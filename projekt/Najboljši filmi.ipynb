# %%
import pandas as pd

# %%
filmi = pd.read_csv('csv-datoteke/filmi.csv', index_col='id')
igralci = pd.read_csv('csv-datoteke/igralci.csv', index_col='id')
zanri = pd.read_csv('csv-datoteke/zanri.csv', index_col='id')
vloge = pd.read_csv('csv-datoteke/vloge.csv')
dolocitve_zanra = pd.read_csv('csv-datoteke/dolocitve_zanra.csv')

# %%
filmi.head()
# Out:
#                                      naslov  leto  ocena
# id
# 103064           Terminator 2: Judgment Day  1991    8.5
# 120746                    The Mask of Zorro  1998    6.7
# 97576    Indiana Jones and the Last Crusade  1989    8.3
# 1646971          How to Train Your Dragon 2  2014    7.9
# 49833                  The Ten Commandments  1956    7.9

# %%
igralci.head()
# Out:
#                   ime
# id
# 136797   Steve Carell
# 862026  Ingrid Thulin
# 375609  Brigitte Helm
# 1472           Jet Li
# 10736       Amy Adams

# %%
igralci.loc[1472]
# Out:
# ime    Jet Li
# Name: 1472, dtype: object

# %%
filmi.iloc[100]
# Out:
# naslov    Children of Men
# leto                 2006
# ocena                 7.9
# Name: 206634, dtype: object

# %%
filmi.ocena.max()
# Out:
# 9.3000000000000007

# %%
filmi.loc[filmi.ocena.argmax()]
# Out:
# naslov    The Shawshank Redemption
# leto                          1994
# ocena                          9.3
# Name: 111161, dtype: object

# %%
filmi.ocena.argmin()
# Out:
# 92086

# %%
filmi.loc[filmi.ocena.argmin()]
# Out:
# naslov    &#xA1;Three Amigos!
# leto                     1986
# ocena                     6.4
# Name: 92086, dtype: object

# %%
filmi[filmi.leto == 2015]
# Out:
#                                naslov  leto  ocena
# id
# 3863552             Bajrangi Bhaijaan  2015    8.2
# 2488496  Star Wars: The Force Awakens  2015    8.5
# 1798684                      Southpaw  2015    7.5
# 2631186      Baahubali: The Beginning  2015    8.7
# 3460252             The Hateful Eight  2015    8.1
# 2096673                    Inside Out  2015    8.3
# 1392190            Mad Max: Fury Road  2015    8.2
# 3659388                   The Martian  2015    8.1
# 3848892                          Baby  2015    8.1
# 1398426        Straight Outta Compton  2015    8.1
# 1663202                  The Revenant  2015    8.3
# 3076658                         Creed  2015    8.1

# %%
filmi[(filmi.leto < 1950) & (filmi.ocena > 8)]
# Out:
#                                  naslov  leto  ocena
# id
# 21749                       City Lights  1931    8.6
# 38355                     The Big Sleep  1946    8.1
# 15864                     The Gold Rush  1925    8.3
# 36775                  Double Indemnity  1944    8.4
# 25316             It Happened One Night  1934    8.2
# 22100                                 M  1931    8.4
# 17136                        Metropolis  1927    8.3
# 33870                The Maltese Falcon  1941    8.2
# 38787                         Notorious  1946    8.1
# 32976                           Rebecca  1940    8.2
# 33467                      Citizen Kane  1941    8.4
# 41959                     The Third Man  1949    8.3
# 37008                             Laura  1944    8.1
# 18455                           Sunrise  1927    8.4
# 32553                The Great Dictator  1940    8.5
# 31381                Gone with the Wind  1939    8.2
# 17925                       The General  1926    8.3
# ...

# %%
filmi.sort_values(by=['leto', 'ocena'], ascending=[False,True])
# Out:
#                                   naslov  leto  ocena
# id
# 1798684                         Southpaw  2015    7.5
# 3460252                The Hateful Eight  2015    8.1
# 3659388                      The Martian  2015    8.1
# 3848892                             Baby  2015    8.1
# 1398426           Straight Outta Compton  2015    8.1
# 3076658                            Creed  2015    8.1
# 3863552                Bajrangi Bhaijaan  2015    8.2
# 1392190               Mad Max: Fury Road  2015    8.2
# 2096673                       Inside Out  2015    8.3
# 1663202                     The Revenant  2015    8.3
# 2488496     Star Wars: The Force Awakens  2015    8.5
# 2631186         Baahubali: The Beginning  2015    8.7
# 3416742        What We Do in the Shadows  2014    7.6
# 3169706                            Pride  2014    7.8
# 1490017                   The Lego Movie  2014    7.8
# 1646971       How to Train Your Dragon 2  2014    7.9
# ...

# %%
filmi_po_letih = filmi.groupby('leto')

# %%
filmi_po_letih.mean().head()
# Out:
#       ocena
# leto
# 1920   8.10
# 1921   8.40
# 1922   8.00
# 1925   8.15
# 1926   8.30

# %%
filmi_po_desetletjih = filmi.groupby(10 * (filmi.leto // 10))

# %%
filmi_po_desetletjih.mean()
# Out:
#              leto     ocena
# leto
# 1920  1924.125000  8.225000
# 1930  1934.722222  8.072222
# 1940  1943.523810  8.104762
# 1950  1955.025000  8.127500
# 1960  1964.558140  8.027907
# 1970  1974.695652  8.028261
# 1980  1984.800000  7.921538
# 1990  1994.877551  7.950000
# 2000  2004.651429  7.878286
# 2010  2012.633333  7.992222

# %%
igralci.ime.apply(lambda x: x.split(' ', 1))
# Out:
# id
# 136797              [Steve, Carell]
# 862026             [Ingrid, Thulin]
# 375609             [Brigitte, Helm]
# 1472                      [Jet, Li]
# 10736                  [Amy, Adams]
# 855417               [Akira, Terao]
# 160                  [Ethan, Hawke]
# 2401020             [Will, Poulter]
# 2299825                    [Ileana]
# 534856                   [Madhavan]
# 492249     [Konstantin, Lavronenko]
# 926209            [Steve, Whitmire]
# 2104            [Paulette, Goddard]
# 564215              [James, McAvoy]
# 347                    [Tim, Curry]
# 1082477                  [Omar, Sy]
# 681                 [Vince, Vaughn]
# 662            [Kiefer, Sutherland]
# 751426          [Rosalind, Russell]
# 304                  [Linda, Blair]
# 4778                [Adrien, Brody]
# 470981        [Thomas, Kretschmann]
# 1075                [Peter, Coyote]
# 329481          [Ginnifer, Goodwin]
# 5028                 [Kate, Hudson]
# 843                [Anne, Bancroft]
# ...

# %%
dolocitve_zanra.join(filmi, on=['film']).groupby('zanr')['ocena'].mean().sort_values()
# Out:
# zanr
# western      7.706154
# sport        7.753846
# music        7.791304
# horror       7.875806
# musical      7.905435
# animation    8.009581
# biography    8.012766
# history      8.015556
# romance      8.028191
# family       8.038506
# comedy       8.045247
# fantasy      8.134783
# adventure    8.154698
# drama        8.154873
# film_noir    8.180000
# war          8.188525
# action       8.191327
# thriller     8.229333
# sci_fi       8.240458
# mystery      8.252308
# crime        8.303704
# Name: ocena, dtype: float64

# %%
vloge.join(filmi, on=['film']).groupby('igralec').mean().join(igralci).sort_values(by='ocena')
# Out:
#                    film         leto     ocena                   ime
# igralec
# 1737       92086.000000  1986.000000  6.400000          Martin Short
# 2309517  1210819.000000  2013.000000  6.500000          Armie Hammer
# 4959      104231.000000  1992.000000  6.500000         Thomas Gibson
# 1209     1210819.000000  2013.000000  6.500000      William Fichtner
# 598       111756.000000  1994.000000  6.600000          Dennis Quaid
# 5154      184894.000000  2000.000000  6.600000              Lucy Liu
# 329       184894.000000  2000.000000  6.600000           Jackie Chan
# 1876      120746.000000  1998.000000  6.700000  Catherine Zeta-Jones
# 733196    317648.000000  2004.000000  6.700000     Zuleikha Robinson
# 662        96487.000000  1988.000000  6.800000     Kiefer Sutherland
# 389        96487.000000  1988.000000  6.800000        Emilio Estevez
# 1617       96487.000000  1988.000000  6.800000  Lou Diamond Phillips
# ...
