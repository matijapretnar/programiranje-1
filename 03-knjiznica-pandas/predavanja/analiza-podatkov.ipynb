# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # Analiza podatkov
#
# To je naš prvi _zvečič_
#
# $$x_{1, 2} = \frac{-b \pm \sqrt{b^2 - 4 a c}}{2 a}$$

# %%
import pandas as pd

# %%
filmi = pd.read_csv("../../02-zajem-podatkov/predavanja/obdelani-podatki/filmi.csv")

# %%
filmi
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# 3        10323                      Das Cabinet des Dr. Caligari       76
# 4        12349                                           The Kid       68
# ...        ...                                               ...      ...
# 9995  11390036                                 A Fall from Grace      115
# 9996  11905962                                           Sputnik      113
# 9997  12393526                                           Bulbbul       94
# 9998  12567088                                    Raat Akeli Hai      149
# 9999  12749596                                              Host       57
#
#       leto  ocena  metascore  glasovi    zasluzek oznaka  \
# ...

# %%
filmi[50:70]
# Out:
#        id                                 naslov  dolzina  leto  ocena  \
# 50  23563           Das Testament des Dr. Mabuse      122  1933    8.0
# 51  23622                          Tezave v raju       83  1932    8.0
# 52  23649                                 Vampyr       75  1932    7.5
# 53  23694                           White Zombie       69  1932    6.3
# 54  23969                 Nora vojna bratov Marx       69  1933    7.8
# 55  24034                            42nd Street       89  1933    7.4
# 56  24184                         Nevidni človek       71  1933    7.7
# 57  24188                   Island of Lost Souls       70  1932    7.4
# 58  24216                              King Kong      100  1933    7.9
# 59  24601                     Sons of the Desert       68  1933    7.6
# 60  24844  Atalanta ali trabakula, ki plove mimo       89  1934    7.8
# 61  24894                          The Black Cat       65  1934    7.0
# ...

# %%
pd.options.display.max_rows = 6

# %%
filmi
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# ...        ...                                               ...      ...
# 9997  12393526                                           Bulbbul       94
# 9998  12567088                                    Raat Akeli Hai      149
# 9999  12749596                                              Host       57
#
#       leto  ocena  metascore  glasovi    zasluzek oznaka  \
# 0     1915    6.3        NaN    22363  10000000.0    NaN
# 1     1916    7.7       99.0    13970   2180000.0    NaN
# 2     1919    7.3        NaN     9296         NaN    NaN
# ...    ...    ...        ...      ...         ...    ...
# 9997  2020    6.6        NaN     8381         NaN    NaN
# ...

# %%
filmi[37]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenv/prog-1/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.virtualenv/prog-1/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.virtualenv/prog-1/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 37
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
filmi[37:38]
# Out:
#        id        naslov  dolzina  leto  ocena  metascore  glasovi  zasluzek  \
# 37  21884  Frankenstein       70  1931    7.8       91.0    63907       NaN
#
#    oznaka                                               opis
# 37    NaN  Dr. Frankenstein dares to tamper with life and...

# %%
filmi.iloc[37]
# Out:
# id                                                      21884
# naslov                                           Frankenstein
# dolzina                                                    70
#                                   ...
# zasluzek                                                  NaN
# oznaka                                                    NaN
# opis        Dr. Frankenstein dares to tamper with life and...
# Name: 37, Length: 10, dtype: object

# %%
filmi['dolzina']
# Out:
# 0       195
# 1       163
# 2        90
#        ...
# 9997     94
# 9998    149
# 9999     57
# Name: dolzina, Length: 10000, dtype: int64

# %%
filmi.dolzina
# Out:
# 0       195
# 1       163
# 2        90
#        ...
# 9997     94
# 9998    149
# 9999     57
# Name: dolzina, Length: 10000, dtype: int64

# %%
filmi.head(5)
# Out:
#       id                                            naslov  dolzina  leto  \
# 0   4972                             The Birth of a Nation      195  1915
# 1   6864  Intolerance: Love's Struggle Throughout the Ages      163  1916
# 2   9968    Broken Blossoms or The Yellow Man and the Girl       90  1919
# 3  10323                      Das Cabinet des Dr. Caligari       76  1920
# 4  12349                                           The Kid       68  1921
#
#    ocena  metascore  glasovi    zasluzek oznaka  \
# 0    6.3        NaN    22363  10000000.0    NaN
# 1    7.7       99.0    13970   2180000.0    NaN
# 2    7.3        NaN     9296         NaN    NaN
# 3    8.1        NaN    56089         NaN    NaN
# 4    8.3        NaN   110278   5450000.0    NaN
#
#                                                 opis
# 0  The Stoneman family finds its friendship with ...
# 1  The story of a poor young woman, separated by ...
# 2  A frail waif, abused by her brutal boxer fathe...
# ...

# %%
malo_filmov = filmi[:6]

# %%
malo_filmov
# Out:
#       id                                            naslov  dolzina  leto  \
# 0   4972                             The Birth of a Nation      195  1915
# 1   6864  Intolerance: Love's Struggle Throughout the Ages      163  1916
# 2   9968    Broken Blossoms or The Yellow Man and the Girl       90  1919
# 3  10323                      Das Cabinet des Dr. Caligari       76  1920
# 4  12349                                           The Kid       68  1921
# 5  12364                                         Körkarlen      107  1921
#
#    ocena  metascore  glasovi    zasluzek oznaka  \
# 0    6.3        NaN    22363  10000000.0    NaN
# 1    7.7       99.0    13970   2180000.0    NaN
# 2    7.3        NaN     9296         NaN    NaN
# 3    8.1        NaN    56089         NaN    NaN
# 4    8.3        NaN   110278   5450000.0    NaN
# 5    8.1        NaN    10158         NaN    NaN
#
#                                                 opis
# ...

# %%
malo_filmov[[True, False, False, True, False, True]]
# Out:
#       id                        naslov  dolzina  leto  ocena  metascore  \
# 0   4972         The Birth of a Nation      195  1915    6.3        NaN
# 3  10323  Das Cabinet des Dr. Caligari       76  1920    8.1        NaN
# 5  12364                     Körkarlen      107  1921    8.1        NaN
#
#    glasovi    zasluzek oznaka  \
# 0    22363  10000000.0    NaN
# 3    56089         NaN    NaN
# 5    10158         NaN    NaN
#
#                                                 opis
# 0  The Stoneman family finds its friendship with ...
# 3  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 5  On New Year's Eve, the driver of a ghostly car...

# %%
filmi.dolzina > 180
# Out:
# 0        True
# 1       False
# 2       False
#         ...
# 9997    False
# 9998    False
# 9999    False
# Name: dolzina, Length: 10000, dtype: bool

# %%
filmi[((filmi.dolzina > 180) & (filmi.ocena < 6)) | ((filmi.dolzina < 60) & (filmi.ocena > 8))]
# Out:
#            id                     naslov  dolzina  leto  ocena  metascore  \
# 11      15324               Sherlock Jr.       45  1924    8.2        NaN
# 9009  4107858  MSG: The Messenger of God      197  2015    5.9        NaN
#
#       glasovi  zasluzek oznaka  \
# 11      40303  977375.0    NaN
# 9009    11146       NaN    NaN
#
#                                                    opis
# 11    A film projectionist longs to be a detective, ...
# 9009  Guru Ji is a social reformer who works to help...

# %%
filmi[
    ['dolzina', 'leto', 'ocena']
][
    filmi.leto >= 2015
].mean(
)
# Out:
# dolzina     111.262423
# leto       2017.061977
# ocena         6.439084
# dtype: float64

# %%
filmi[
    ['dolzina', 'leto', 'ocena', 'oznaka']
].groupby(
    ['oznaka', 'leto']
).mean()
# Out:
#                   dolzina     ocena
# oznaka   leto
# 15+      1986   74.000000  7.200000
# Approved 1937   83.000000  7.600000
#          1949   83.000000  7.300000
# G        1931   87.000000  8.500000
#          1937  117.000000  8.000000
# ...                   ...       ...
# R        2020  107.724138  6.075862
# Unrated  2004  105.000000  7.600000
#          2008  103.000000  6.900000
#          2013  102.000000  6.200000
#          2017   86.000000  6.400000
#
# [244 rows x 2 columns]

# %%
pd.options.display.max_rows = 15

# %%
filmi[
    ['leto', 'ocena']
].groupby(
    'leto'
).max().plot()
# Out:
# <AxesSubplot:xlabel='leto'>

# %%
filmi[
    ['leto', 'ocena']
][
    filmi.ocena > 8
].groupby(
    'leto'
).count().plot()
# Out:
# <AxesSubplot:xlabel='leto'>

# %%
filmi[
    ['leto', 'ocena']
].groupby(
    'leto'
).count().plot()
# Out:
# <AxesSubplot:xlabel='leto'>

# %%
filmi[
    ['leto', 'ocena']
].groupby(
    'leto'
).median().plot()
# Out:
# <AxesSubplot:xlabel='leto'>

# %%
vsi_filmi_po_letih = filmi[
    ['leto', 'ocena']
].groupby(
    'leto'
).count()

# %%
vsi_dobri_filmi_po_letih = filmi[
    ['leto', 'ocena']
][
    filmi.ocena > 8
].groupby(
    'leto'
).count()

# %%
delez_dobrih = vsi_dobri_filmi_po_letih / vsi_filmi_po_letih

# %%
delez_dobrih.tail(50).idxmax()
# Out:
# ocena    1975
# dtype: int64

# %%
filmi[(filmi.ocena > 8) & (filmi.leto == 1975)].sort_values('glasovi', ascending=False)
# Out:
#           id                           naslov  dolzina  leto  ocena  \
# 1036   73486       Let nad kukavičjim gnezdom      133  1975    8.7
# 1000   71853  Monty Python and the Holy Grail       91  1975    8.2
# 1017   72684                     Barry Lyndon      185  1975    8.1
# 1046   73707             Veter, plamen in bes      204  1975    8.2
# 1016   72443                           Zrcalo      107  1975    8.1
# 4058  252487                   Hababam Sinifi       87  1975    9.3
# 985    71411                      Dersu Uzala      142  1975    8.3
# 1027   73000              Flåklypa Grand Prix       88  1975    8.5
# 1019   72783                    Chupke Chupke      146  1975    8.3
# 1021   72860                          Deewaar      174  1975    8.1
#
#       metascore  glasovi     zasluzek oznaka  \
# 1036       83.0   899748  112000000.0    NaN
# 1000       91.0   494020    1229197.0    NaN
# 1017       89.0   146428          NaN    NaN
# ...

# %%
filmi.ocena.plot()
# Out:
# <AxesSubplot:>

# %%
filmi.plot.scatter('ocena', 'metascore')
# Out:
# <AxesSubplot:xlabel='ocena', ylabel='metascore'>

# %%
filmi.sort_values('zasluzek', ascending=False).head(20).plot.bar(x='naslov', y='zasluzek')
# Out:
# <AxesSubplot:xlabel='naslov'>

# %%
zanri = pd.read_csv("../../02-zajem-podatkov/predavanja/obdelani-podatki/zanri.csv")

# %%
filmi
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# 3        10323                      Das Cabinet des Dr. Caligari       76
# 4        12349                                           The Kid       68
# ...        ...                                               ...      ...
# 9995  11390036                                 A Fall from Grace      115
# 9996  11905962                                           Sputnik      113
# 9997  12393526                                           Bulbbul       94
# 9998  12567088                                    Raat Akeli Hai      149
# 9999  12749596                                              Host       57
#
#       leto  ocena  metascore  glasovi    zasluzek oznaka  \
# ...

# %%
zanri
# Out:
#            film     zanr
# 0          4972    Drama
# 1          4972  History
# 2          4972      War
# 3          6864    Drama
# 4          6864  History
# ...         ...      ...
# 25521  12567088    Crime
# 25522  12567088    Drama
# 25523  12567088  Mystery
# 25524  12749596   Horror
# 25525  12749596  Mystery
#
# [25526 rows x 2 columns]

# %%
filmi_z_zanri
# Out:
#              id                                            naslov  dolzina  \
# 0          4972                             The Birth of a Nation      195
# 1          4972                             The Birth of a Nation      195
# 2          4972                             The Birth of a Nation      195
# 3          6864  Intolerance: Love's Struggle Throughout the Ages      163
# 4          6864  Intolerance: Love's Struggle Throughout the Ages      163
# ...         ...                                               ...      ...
# 25521  12567088                                    Raat Akeli Hai      149
# 25522  12567088                                    Raat Akeli Hai      149
# 25523  12567088                                    Raat Akeli Hai      149
# 25524  12749596                                              Host       57
# 25525  12749596                                              Host       57
#
#        leto  ocena  metascore  glasovi    zasluzek oznaka  \
# ...

# %%
filmi_z_zanri = pd.merge(filmi, zanri, left_on="id", right_on="film")

# %%
filmi_z_zanri.groupby("zanr").count().sort_values('metascore').metascore.plot.bar()
# Out:
# <AxesSubplot:xlabel='zanr'>

# %%
osebe = pd.read_csv(
    "../../02-zajem-podatkov/predavanja/obdelani-podatki/osebe.csv"
)

# %%
vloge = pd.read_csv(
    "../../02-zajem-podatkov/predavanja/obdelani-podatki/vloge.csv"
)

# %%
osebe
# Out:
#              id               ime
# 0             1      Fred Astaire
# 1             2     Lauren Bacall
# 2             3   Brigitte Bardot
# 3             4      John Belushi
# 4             5    Ingmar Bergman
# ...         ...               ...
# 19240  11668342     Yeon Je Hyung
# 19241  11717110   Mhairi Anderson
# 19242  11722505      Aakshath Das
# 19243  11823172    Serhan Ergören
# 19244  11859619  Huseyin Adiguzel
#
# [19245 rows x 2 columns]

# %%
zanri
# Out:
#            film     zanr
# 0          4972    Drama
# 1          4972  History
# 2          4972      War
# 3          6864    Drama
# 4          6864  History
# ...         ...      ...
# 25521  12567088    Crime
# 25522  12567088    Drama
# 25523  12567088  Mystery
# 25524  12749596   Horror
# 25525  12749596  Mystery
#
# [25526 rows x 2 columns]

# %%
vsi_podatki = pd.merge(
    pd.merge(osebe, vloge, left_on="id", right_on="oseba"),
    filmi,
    left_on="film",
    right_on="id"
)

# %%
ocene_reziserjev = vsi_podatki[vsi_podatki.vloga == 'R'][
    ['ime', 'ocena']
].groupby('ime')

# %%
ocene_reziserjev.mean(
)[
    ocene_reziserjev.count() > 5
].sort_values(
    'ocena', ascending=False
).head(20)
# Out:
#                          ocena
# ime
# Ertem Egilmez         8.700000
# Sergio Leone          8.266667
# Charles Chaplin       8.250000
# Christopher Nolan     8.209091
# Akira Kurosawa        8.143750
# Andrei Tarkovsky      8.114286
# Hayao Miyazaki        8.018182
# Mani Ratnam           8.014286
# Fritz Lang            8.000000
# Frank Capra           7.987500
# Ingmar Bergman        7.975000
# Buster Keaton         7.957143
# Krzysztof Kieslowski  7.942857
# Emir Kusturica        7.866667
# Quentin Tarantino     7.861538
# Robert Bresson        7.850000
# Giuseppe Tornatore    7.833333
# Luis Buñuel           7.830000
# Michael Powell        7.828571
# Jean-Pierre Melville  7.816667
