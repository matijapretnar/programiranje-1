# %% [markdown]
# # Analiza filmov
#
# To so zapiski pri predmetu _Programiranje 1_, na programu _Matematika_, kjer se uči tudi stvari kot so
# $$\int_a^b f(x) \, dx$$

# %% [markdown]
# ## Nalaganje podatkov

# %%
import pandas as pd

# %%
filmi = pd.read_csv("../../02-zajem-podatkov/predavanja/obdelani-podatki/filmi.csv", index_col="id")

# %%
filmi
# Out:
#                                                      naslov  dolzina  leto  \
# id
# 4972                                  The Birth of a Nation      195  1915
# 6864                                            Intolerance      197  1916
# 9968                                        Broken Blossoms       90  1919
# 10323                           The Cabinet of Dr. Caligari       67  1920
# 12349                                               The Kid       68  1921
# ...                                                     ...      ...   ...
# 18568902                                 Kaun Pravin Tambe?      134  2022
# 18689424  Batman v Superman: Dawn of Justice - Ultimate ...      182  2016
# 18968540                                        Incantation      110  2022
# 20850406                                         Sita Ramam      163  2022
# 21279138                                 Maid in Malacañang      114  2022
#
#           ocena  metascore  glasovi    zasluzek     oznaka  \
# ...

# %%
filmi.head(5)
# Out:
#       id                       naslov  dolzina  leto  ocena  metascore  \
# 0   4972        The Birth of a Nation      195  1915    6.2        NaN
# 1   6864                  Intolerance      197  1916    7.7       99.0
# 2   9968              Broken Blossoms       90  1919    7.3        NaN
# 3  10323  The Cabinet of Dr. Caligari       67  1920    8.0        NaN
# 4  12349                      The Kid       68  1921    8.3        NaN
#
#    glasovi    zasluzek     oznaka  \
# 0    24890  10000000.0      TV-PG
# 1    15670   2180000.0     Passed
# 2    10423         NaN  Not Rated
# 3    64133         NaN  Not Rated
# 4   126513   5450000.0     Passed
#
#                                                 opis
# 0  The Stoneman family finds its friendship with ...
# 1  The story of a poor young woman separated by p...
# 2  A frail waif, abused by her brutal boxer fathe...
# 3  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 4  The Tramp cares for an abandoned child, but ev...

# %%
filmi.iloc[3]
# Out:
# id                                                       10323
# naslov                             The Cabinet of Dr. Caligari
# dolzina                                                     67
# leto                                                      1920
# ocena                                                      8.0
# metascore                                                  NaN
# glasovi                                                  64133
# zasluzek                                                   NaN
# oznaka                                               Not Rated
# opis         Hypnotist Dr. Caligari uses a somnambulist, Ce...
# Name: 3, dtype: object

# %%
filmi[["naslov", "leto"]]
# Out:
#                                                  naslov  leto
# 0                                 The Birth of a Nation  1915
# 1                                           Intolerance  1916
# 2                                       Broken Blossoms  1919
# 3                           The Cabinet of Dr. Caligari  1920
# 4                                               The Kid  1921
# ...                                                 ...   ...
# 9994                                 Kaun Pravin Tambe?  2022
# 9995  Batman v Superman: Dawn of Justice - Ultimate ...  2016
# 9996                                        Incantation  2022
# 9997                                         Sita Ramam  2022
# 9998                                 Maid in Malacañang  2022
#
# [9999 rows x 2 columns]

# %%
filmi[["naslov"]]
# Out:
#                                                  naslov
# 0                                 The Birth of a Nation
# 1                                           Intolerance
# 2                                       Broken Blossoms
# 3                           The Cabinet of Dr. Caligari
# 4                                               The Kid
# ...                                                 ...
# 9994                                 Kaun Pravin Tambe?
# 9995  Batman v Superman: Dawn of Justice - Ultimate ...
# 9996                                        Incantation
# 9997                                         Sita Ramam
# 9998                                 Maid in Malacañang
#
# [9999 rows x 1 columns]

# %%
filmi.ocena > 8
# Out:
# id
# 4972        False
# 6864        False
# 9968        False
# 10323       False
# 12349        True
#             ...
# 18568902     True
# 18689424    False
# 18968540    False
# 20850406     True
# 21279138    False
# Name: ocena, Length: 9999, dtype: bool

# %%
filmi[filmi.ocena > 8]
# Out:
#                                                      naslov  dolzina  leto  \
# id
# 12349                                               The Kid       68  1921
# 14429                                          Safety Last!       74  1923
# 15324                                          Sherlock Jr.       45  1924
# 15864                                         The Gold Rush       95  1925
# 15881                                                 Greed      140  1924
# ...                                                     ...      ...   ...
# 15327088                                            Kantara      148  2022
# 15654262                                               Chup      135  2022
# 16492678  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...       87  2021
# 18568902                                 Kaun Pravin Tambe?      134  2022
# 20850406                                         Sita Ramam      163  2022
#
#           ocena  metascore  glasovi   zasluzek     oznaka  \
# ...

# %%
filmi = filmi[filmi.glasovi > 500000]

# %%
filmi[(filmi.ocena > 8) & (filmi.dolzina < 90)]
# Out:
#                naslov  dolzina  leto  ocena  metascore  glasovi     zasluzek  \
# id
# 110357  The Lion King       88  1994    8.5       88.0  1048629  422783777.0
# 114709      Toy Story       81  1995    8.3       95.0   986195  191796233.0
#
#        oznaka                                               opis
# id
# 110357      G  Lion prince Simba and his father are targeted ...
# 114709      G  A cowboy doll is profoundly threatened and jea...

# %%
filmi[(filmi.ocena < 6) & (filmi.dolzina > 120)]
# Out:
#                 naslov  dolzina  leto  ocena  metascore  glasovi     zasluzek  \
# id
# 1386697  Suicide Squad      123  2016    5.9       40.0   682544  325100054.0
#
#         oznaka                                               opis
# id
# 1386697  PG-13  A secret government agency recruits some of th...

# %%
filmi["zanimivost"] = filmi.ocena / filmi.dolzina
# Out:
# /var/folders/tm/2v5mtql172qb87lg0ksjgwxh0000gn/T/ipykernel_90726/3574355924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filmi["zanimivost"] = filmi.ocena / filmi.dolzina

# %%
filmi
# Out:
#                                   naslov  dolzina  leto  ocena  metascore  \
# id
# 34583                         Casablanca      102  1942    8.5      100.0
# 50083                       12 Angry Men       96  1957    9.0       96.0
# 54215                             Psycho      109  1960    8.5       97.0
# 60196     The Good, the Bad and the Ugly      178  1966    8.8       90.0
# 62622              2001: A Space Odyssey      149  1968    8.3       84.0
# ...                                  ...      ...   ...    ...        ...
# 8579674                             1917      119  2019    8.2       78.0
# 8946378                       Knives Out      130  2019    7.9       82.0
# 10811166               The Kashmir Files      170  2022    8.3        NaN
# 10872600         Spider-Man: No Way Home      148  2021    8.3       71.0
# 11286314                   Don't Look Up      138  2021    7.2       49.0
#
#           glasovi     zasluzek    oznaka  \
# id
# ...

# %%
filmi.sort_values("zanimivost")
# Out:
#                                                 naslov  dolzina  leto  ocena  \
# id
# 120338                                         Titanic      194  1997    7.9
# 449088        Pirates of the Caribbean: At World's End      169  2007    7.1
# 2975590             Batman v Superman: Dawn of Justice      152  2016    6.4
# 71562                            The Godfather Part II      202  1974    9.0
# 167260   The Lord of the Rings: The Return of the King      201  2003    9.0
# ...                                                ...      ...   ...    ...
# 198781                                  Monsters, Inc.       92  2001    8.1
# 71853                  Monty Python and the Holy Grail       91  1975    8.2
# 50083                                     12 Angry Men       96  1957    9.0
# 110357                                   The Lion King       88  1994    8.5
# 114709                                       Toy Story       81  1995    8.3
#
# ...

# %%
filmi_mlajsi_od_studentov = filmi[filmi.leto > 2002]

# %%
filmi_mlajsi_od_studentov
# Out:
#                                                  naslov  dolzina  leto  ocena  \
# id
# 121766     Star Wars: Episode III - Revenge of the Sith      140  2005    7.6
# 167260    The Lord of the Rings: The Return of the King      201  2003    9.0
# 234215                              The Matrix Reloaded      138  2003    7.2
# 242653                           The Matrix Revolutions      129  2003    6.7
# 266543                                     Finding Nemo      100  2003    8.2
# ...                                                 ...      ...   ...    ...
# 8579674                                            1917      119  2019    8.2
# 8946378                                      Knives Out      130  2019    7.9
# 10811166                              The Kashmir Files      170  2022    8.3
# 10872600                        Spider-Man: No Way Home      148  2021    8.3
# 11286314                                  Don't Look Up      138  2021    7.2
#
# ...

# %%
filmi.sort_values(["leto", "ocena"], ascending=[True, False])
# Out:
#                                   naslov  dolzina  leto  ocena  metascore  \
# id
# 34583                         Casablanca      102  1942    8.5      100.0
# 50083                       12 Angry Men       96  1957    9.0       96.0
# 54215                             Psycho      109  1960    8.5       97.0
# 60196     The Good, the Bad and the Ugly      178  1966    8.8       90.0
# 62622              2001: A Space Odyssey      149  1968    8.3       84.0
# ...                                  ...      ...   ...    ...        ...
# 10872600         Spider-Man: No Way Home      148  2021    8.3       71.0
# 1160419                             Dune      155  2021    8.0       74.0
# 11286314                   Don't Look Up      138  2021    7.2       49.0
# 10811166               The Kashmir Files      170  2022    8.3        NaN
# 1877830                       The Batman      176  2022    7.9       72.0
#
#           glasovi     zasluzek    oznaka  \
# id
# ...

# %%
filmi.groupby("leto").dolzina.mean().plot()
# Out:
# <AxesSubplot: xlabel='leto'>

# %%
filmi_z_najvecjim_zasluzkom_v_letu_2002 = filmi[
    filmi.leto == 2002
].sort_values(
    "zasluzek", ascending=False
).head(
    20
)

# %%
filmi_z_najvecjim_zasluzkom_v_letu_2002.plot.bar(x="naslov", y="zasluzek")
# Out:
# <AxesSubplot: xlabel='naslov'>

# %%
filmi.sort_values("zasluzek").plot(x="zasluzek", y="ocena")
# Out:
# <AxesSubplot: xlabel='zasluzek'>

# %%
filmi
# Out:
#                                                      naslov  dolzina  leto  \
# id
# 4972                                  The Birth of a Nation      195  1915
# 6864                                            Intolerance      197  1916
# 9968                                        Broken Blossoms       90  1919
# 10323                           The Cabinet of Dr. Caligari       67  1920
# 12349                                               The Kid       68  1921
# ...                                                     ...      ...   ...
# 18568902                                 Kaun Pravin Tambe?      134  2022
# 18689424  Batman v Superman: Dawn of Justice - Ultimate ...      182  2016
# 18968540                                        Incantation      110  2022
# 20850406                                         Sita Ramam      163  2022
# 21279138                                 Maid in Malacañang      114  2022
#
#           ocena  metascore  glasovi    zasluzek     oznaka  \
# ...

# %%
zanri = pd.read_csv("../../02-zajem-podatkov/predavanja/obdelani-podatki/zanri.csv")

# %%
zanri
# Out:
#            film     zanr
# 0          4972    Drama
# 1          4972  History
# 2          4972      War
# 3          6864    Drama
# 4          6864  History
# ...         ...      ...
# 25801  18968540  Mystery
# 25802  20850406   Action
# 25803  20850406    Drama
# 25804  20850406  Mystery
# 25805  21279138    Drama
#
# [25806 rows x 2 columns]

# %%
filmi
# Out:
#                                                      naslov  dolzina  leto  \
# id
# 4972                                  The Birth of a Nation      195  1915
# 6864                                            Intolerance      197  1916
# 9968                                        Broken Blossoms       90  1919
# 10323                           The Cabinet of Dr. Caligari       67  1920
# 12349                                               The Kid       68  1921
# ...                                                     ...      ...   ...
# 18568902                                 Kaun Pravin Tambe?      134  2022
# 18689424  Batman v Superman: Dawn of Justice - Ultimate ...      182  2016
# 18968540                                        Incantation      110  2022
# 20850406                                         Sita Ramam      163  2022
# 21279138                                 Maid in Malacañang      114  2022
#
#           ocena  metascore  glasovi    zasluzek     oznaka  \
# ...

# %%
filmi_z_zanri = pd.merge(filmi, zanri, left_on="id", right_on="film")

# %%
filmi.groupby(["leto", "oznaka"]).mean()
# Out:
# /var/folders/tm/2v5mtql172qb87lg0ksjgwxh0000gn/T/ipykernel_90726/2927338470.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   filmi.groupby(["leto", "oznaka"]).mean()
#                    dolzina     ocena  metascore        glasovi    zasluzek
# leto oznaka
# 1915 TV-PG      195.000000  6.200000        NaN   24890.000000  10000000.0
# 1916 Passed     197.000000  7.700000  99.000000   15670.000000   2180000.0
# 1919 Not Rated   90.000000  7.300000        NaN   10423.000000         NaN
# 1920 Not Rated   67.000000  8.000000        NaN   64133.000000         NaN
# 1921 Not Rated  107.000000  8.000000        NaN   12624.000000         NaN
# ...                    ...       ...        ...            ...         ...
# 2022 PG         102.000000  6.326667  53.533333   45012.266667         NaN
# ...

# %%
(filmi_z_zanri[filmi_z_zanri.zanr == "Animation"].groupby("leto").size() / filmi.groupby("leto").size()).plot()
# Out:
# <AxesSubplot: xlabel='leto'>

# %%
filmi_z_zanri.groupby("zanr").mean().plot.bar(y="dolzina")
# Out:
# /var/folders/tm/2v5mtql172qb87lg0ksjgwxh0000gn/T/ipykernel_90726/1321592591.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   filmi_z_zanri.groupby("zanr").mean().plot.bar(y="dolzina")
# <AxesSubplot: xlabel='zanr'>

# %%
grozljivke = zanri[zanri.zanr=="Horror"]

# %%
druzinski = zanri[zanri.zanr=="Family"]

# %%
grozljivke
# Out:
#            film    zanr
# 7         10323  Horror
# 15        12364  Horror
# 17        13442  Horror
# 40        16220  Horror
# 45        16847  Horror
# ...         ...     ...
# 25722  14253846  Horror
# 25748  14549466  Horror
# 25785  15474916  Horror
# 25789  15791034  Horror
# 25800  18968540  Horror
#
# [1267 rows x 2 columns]

# %%
druzinski
# Out:
#            film    zanr
# 12        12349  Family
# 67        18742  Family
# 69        18773  Family
# 82        20640  Family
# 104       22158  Family
# ...         ...     ...
# 25430  11681250  Family
# 25470  11909878  Family
# 25549  12834962  Family
# 25620  13236566  Family
# 25649  13449624  Family
#
# [470 rows x 2 columns]

# %%
pd.merge(grozljivke, druzinski, on="film")
# Out:
# Empty DataFrame
# Columns: [film, zanr_x, zanr_y]
# Index: []

# %%
pd.merge(
    pd.merge(zanri[zanri.zanr=="Horror"], zanri[zanri.zanr=="Romance"], on="film"),
    filmi,
    left_on="film",
    right_on="id"
)
# Out:
#        film  zanr_x   zanr_y                            naslov  dolzina  leto  \
# 0     34398  Horror  Romance                      The Wolf Man       70  1941
# 1     79073  Horror  Romance                           Dracula      109  1979
# 2     92240  Horror  Romance                        The Wraith       93  1986
# 3    109836  Horror  Romance       Mary Shelley's Frankenstein      123  1994
# 4    111742  Horror  Romance                              Wolf      125  1994
# 5    117002  Horror  Romance                       Mary Reilly      108  1996
# 6   1545106  Horror  Romance                             Vamps       92  2012
# 7   1588173  Horror  Romance                       Warm Bodies       98  2013
# 8   2326554  Horror  Romance  A Girl Walks Home Alone at Night      101  2014
# 9   3339674  Horror  Romance                    Burying the Ex       89  2014
# 10  3395184  Horror  Romance                            Spring      109  2014
# ...

# %%
osebe = pd.read_csv("../../02-zajem-podatkov/predavanja/obdelani-podatki/osebe.csv")
vloge = pd.read_csv("../../02-zajem-podatkov/predavanja/obdelani-podatki/vloge.csv")

# %%
filmi_z_osebami = pd.merge(pd.merge(filmi, vloge, left_on="id", right_on="film"), osebe, left_on="oseba", right_on="id")

# %%
filmi_z_osebami.groupby(["id", "ime"]).size().sort_values().tail(20).plot.bar()
# Out:
# <AxesSubplot: xlabel='id,ime'>
