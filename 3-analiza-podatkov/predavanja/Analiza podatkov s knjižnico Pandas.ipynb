# %% [markdown]
# # Analiza podatkov s knjižnico Pandas
#
# Spodaj je pregled najosnovnejših metod, ki jih ponuja knjižnica Pandas. Vsaka od naštetih metod ponuja še cel kup dodatnih možnosti, ki so natančno opisane v [uradni dokumentaciji](http://pandas.pydata.org/pandas-docs/stable/). Z branjem dokumentacije se vam seveda najbolj splača začeti pri [uvodih](http://pandas.pydata.org/pandas-docs/stable/tutorials.html).

# %% [markdown]
# ### Predpriprava

# %%
# naložimo paket
import pandas as pd

# naložimo razpredelnico, s katero bomo delali
filmi = pd.read_csv('csv-datoteke/filmi.csv', index_col='id')

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 20 vrstic
pd.options.display.max_rows = 20

# %% [markdown]
# ## Delo z razpredelnicami

# %% [markdown]
# ### Osnovni izbori elementov razpredelnic

# %% [markdown]
# Z metodo `.head(n=5)` pogledamo prvih `n`, z metodo `.tail(n=5)` pa zadnjih `n` vrstic razpredelnice.

# %%
filmi.head(10)
# Out:
#                                                     naslov  leto  dolzina  \
# id
# 449467                                             Babilon  2006      143
# 110148   Interview with the Vampire: The Vampire Chroni...  1994      123
# 489099                                              Jumper  2008       88
# 1397280                                       Ugrabljena 2  2012       92
# 1245526                                                RED  2010      111
# 87843                          Once Upon a Time in America  1984      229
# 472043                                          Apocalypto  2006      139
# 379786                                            Serenity  2005      119
# 120663                                      Eyes Wide Shut  1999      159
# 381849                                        3:10 to Yuma  2007      122
#
#          ocena  metascore                                               opis
# id
# 449467     7.5         69  Tragedy strikes a married couple on vacation i...
# 110148     7.6         59  A vampire tells his epic life story: love, bet...
# 489099     6.1         35  A teenager with teleportation abilities sudden...
# 1397280    6.3         45  In Istanbul, retired CIA operative Bryan Mills...
# 1245526    7.1         60  When his peaceful life is threatened by a high...
# 87843      8.4         77  An epic mosaic of interrelated characters in s...
# 472043     7.8         68  As the Mayan kingdom faces its decline, a youn...
# 379786     7.9         74  The crew of the ship Serenity try to evade an ...
# 120663     7.4         68  A New York City doctor, who is married to an a...
# 381849     7.7         76  A small-time rancher agrees to hold a captured...

# %%
filmi.tail()
# Out:
#                              naslov  leto  dolzina  ocena  metascore  \
# id
# 96874    Back to the Future Part II  1989      108    7.8         57
# 242653       The Matrix Revolutions  2003      129    6.7         47
# 99487           Edward Scissorhands  1990      105    7.9         74
# 2911666                   John Wick  2014      101    7.3         68
# 356910             Mr. & Mrs. Smith  2005      120    6.5         55
#
#                                                       opis
# id
# 96874    After visiting 2015, Marty McFly must repeat h...
# 242653   The human city of Zion defends itself against ...
# 99487    A gentle man, with scissors for hands, is brou...
# 2911666  An ex-hitman comes out of retirement to track ...
# 356910   A bored married couple is surprised to learn t...

# %% [markdown]
# Z indeksiranjem razpredelnice dostopamo do posameznih stolpcev. Če želimo več stolpcev, moramo za indeks podati seznam vseh oznak. Z rezinami pa dostopamo do izbranih vrstic.

# %%
filmi['naslov']
# Out:
# id
# 449467                                               Babilon
# 110148     Interview with the Vampire: The Vampire Chroni...
# 489099                                                Jumper
# 1397280                                         Ugrabljena 2
# 1245526                                                  RED
# 87843                            Once Upon a Time in America
# 175880                                              Magnolia
# 472043                                            Apocalypto
# 379786                                              Serenity
# 120663                                        Eyes Wide Shut
#                                  ...
# 1659337                      The Perks of Being a Wallflower
# 425112                                              Hot Fuzz
# 289879                                  The Butterfly Effect
# 3460252                                    The Hateful Eight
# 1800241                                      American Hustle
# 96874                             Back to the Future Part II
# 242653                                The Matrix Revolutions
# 99487                                    Edward Scissorhands
# 2911666                                            John Wick
# 356910                                      Mr. & Mrs. Smith
# Name: naslov, Length: 2500, dtype: object

# %%
filmi[['naslov', 'ocena']]
# Out:
#                                                     naslov  ocena
# id
# 449467                                             Babilon    7.5
# 110148   Interview with the Vampire: The Vampire Chroni...    7.6
# 489099                                              Jumper    6.1
# 1397280                                       Ugrabljena 2    6.3
# 1245526                                                RED    7.1
# 87843                          Once Upon a Time in America    8.4
# 472043                                          Apocalypto    7.8
# 379786                                            Serenity    7.9
# 120663                                      Eyes Wide Shut    7.4
# 381849                                        3:10 to Yuma    7.7
# ...                                                    ...    ...
# 1659337                    The Perks of Being a Wallflower    8.0
# 425112                                            Hot Fuzz    7.9
# 289879                                The Butterfly Effect    7.7
# 3460252                                  The Hateful Eight    7.8
# 1800241                                    American Hustle    7.3
# 96874                           Back to the Future Part II    7.8
# 242653                              The Matrix Revolutions    6.7
# 99487                                  Edward Scissorhands    7.9
# 2911666                                          John Wick    7.3
# 356910                                    Mr. & Mrs. Smith    6.5
#
# [2396 rows x 2 columns]

# %%
filmi[120:125]
# Out:
#                         naslov  leto  dolzina  ocena  metascore  \
# id
# 438097   Ice Age: The Meltdown  2006       91    6.8         58
# 1706593              Chronicle  2012       84    7.1         69
# 3799694          The Nice Guys  2016      116    7.4         70
# 1601913               The Grey  2011      117    6.8         64
# 105323        Scent of a Woman  1992      156    8.0         59
#
#                                                       opis
# id
# 438097   Manny, Sid, and Diego discover that the ice ag...
# 1706593  Three high school friends gain superpowers aft...
# 3799694  In 1970s Los Angeles, a mismatched pair of pri...
# 1601913  After their plane crashes in Alaska, six oil w...
# 105323   A prep school student needing money agrees to ...

# %% [markdown]
# Do vrednosti z indeksom `i` dostopamo z `.iloc[i]`, do tiste s ključem `k` pa z `.loc[k]`.

# %%
filmi.iloc[120]
# Out:
# naslov                                   Ice Age: The Meltdown
# leto                                                      2006
# dolzina                                                     91
# ocena                                                      6.8
# metascore                                                   58
# opis         Manny, Sid, and Diego discover that the ice ag...
# Name: 438097, dtype: object

# %%
filmi.loc[97576]
# Out:
# naslov                      Indiana Jones and the Last Crusade
# leto                                                      1989
# dolzina                                                    127
# ocena                                                      8.3
# metascore                                                   65
# opis         In 1938, after his father Professor Henry Jone...
# Name: 97576, dtype: object

# %% [markdown]
# ### Filtriranje in urejanje

# %% [markdown]
# Izbor določenih vrstic razpredelnice naredimo tako, da za indeks podamo stolpec logičnih vrednosti, ki ga dobimo z običajnimi operacijami. V vrnjeni razpredelnici bodo ostale vrstice, pri katerih je v stolpcu vrednost `True`.

# %%
filmi.ocena >= 8
# Out:
# id
# 449467     False
# 110148     False
# 489099     False
# 1397280    False
# 1245526    False
# 87843       True
# 472043     False
# 379786     False
# 120663     False
# 381849     False
#            ...
# 1659337     True
# 425112     False
# 289879     False
# 3460252    False
# 1800241    False
# 96874      False
# 242653     False
# 99487      False
# 2911666    False
# 356910     False
# Name: ocena, Length: 2396, dtype: bool

# %%
filmi[filmi.ocena >= 8]
# Out:
#                                   naslov  leto  dolzina  ocena  metascore  \
# id
# 87843        Once Upon a Time in America  1984      229    8.4         77
# 56592              To Kill a Mockingbird  1962      129    8.3         87
# 53125                 North by Northwest  1959      136    8.3         98
# 64116       Once Upon a Time in the West  1968      165    8.5         80
# 107688    The Nightmare Before Christmas  1993       76    8.0         82
# 71315                          Chinatown  1974      130    8.2         92
# 31381                 Gone with the Wind  1939      238    8.2         97
# 61722                       The Graduate  1967      106    8.0         77
# 56172                 Lawrence of Arabia  1962      216    8.3        100
# 75686                         Annie Hall  1977       93    8.0         92
# ...                                  ...   ...      ...    ...        ...
# 34583                         Casablanca  1942      102    8.5        100
# 75148                              Rocky  1976      120    8.1         70
# 450259                    Krvavi diamant  2006      143    8.0         64
# 469494               There Will Be Blood  2007      158    8.1         93
# 71853    Monty Python and the Holy Grail  1975       91    8.3         93
# 1798709                              Her  2013      126    8.0         90
# 364569                            Oldboy  2003      120    8.4         74
# 95953                           Rain Man  1988      133    8.0         65
# 5013056                          Dunkirk  2017      106    8.0         94
# 1659337  The Perks of Being a Wallflower  2012      103    8.0         67
#
#                                                       opis
# id
# 87843    An epic mosaic of interrelated characters in s...
# 56592    Atticus Finch, a lawyer in the Depression-era ...
# 53125    A hapless New York advertising executive is mi...
# 64116    A mysterious stranger with a harmonica joins f...
# 107688   Jack Skellington, king of Halloween Town, disc...
# 71315    A private detective hired to expose an adulter...
# 31381    A manipulative woman and a roguish man conduct...
# 61722    A disillusioned college graduate finds himself...
# 56172                                         The story of
# 75686    Neurotic New York comedian Alvy Singer falls i...
# ...                                                    ...
# 34583    A cynical nightclub owner protects an old flam...
# 75148    A small-time boxer gets a supremely rare chanc...
# 450259   A fisherman, a smuggler, and a syndicate of bu...
# 469494   A story of family, religion, hatred, oil and m...
# 71853    King Arthur and his Knights of the Round Table...
# 1798709  In a near future, a lonely writer develops an ...
# 364569   After being kidnapped and imprisoned for fifte...
# 95953    Selfish yuppie Charlie Babbitt's father left a...
# 5013056  Allied soldiers from Belgium, the British Empi...
# 1659337  An introvert freshman is taken under the wings...
#
# [329 rows x 6 columns]

# %%
filmi[(filmi.leto > 2010) & (filmi.ocena >= 8.5)]
# Out:
#                          naslov  leto  dolzina  ocena  metascore  \
# id
# 5074352                  Dangal  2016      161    8.5         64
# 5813916         The Mountain II  2016      135    9.4         69
# 816692             Interstellar  2014      169    8.6         74
# 1675434        The Intouchables  2011      112    8.5         57
# 2582802                Whiplash  2014      107    8.5         88
# 4154756  Avengers: Infinity War  2018      149    8.6         68
#
#                                                       opis
# id
# 5074352  A mentally unstable photo developer begins to ...
# 5813916  A drama based on a Texas congressman Charlie W...
# 816692   A team of explorers travel through a wormhole ...
# 1675434  After he becomes a quadriplegic from a paragli...
# 2582802  A promising young drummer enrolls at a cut-thr...
# 4154756  The Avengers and their allies must be willing ...

# %% [markdown]
# Razpredelnico urejamo z metodo `.sort_values`, ki ji podamo ime ali seznam imen stolpcev, po katerih želimo urejati. Po želji lahko tudi povemo, kateri stolpci naj bodo urejeni naraščajoče in kateri padajoče.

# %%
filmi.sort_values('leto')
# Out:
#                           naslov  leto  dolzina  ocena  metascore  \
# id
# 12349                    The Kid  1921       68    8.3         75
# 13442                  Nosferatu  1922       81    8.0         28
# 15864              The Gold Rush  1925       95    8.2         45
# 17925                The General  1926       67    8.2         31
# 17136                 Metropolis  1927      153    8.3         98
# 22100                          M  1931       99    8.4         59
# 21749                City Lights  1931       87    8.5         51
# 24216                  King Kong  1933      100    7.9         90
# 25316      It Happened One Night  1934      105    8.1         87
# 27977               Modern Times  1936       87    8.5         96
# ...                          ...   ...      ...    ...        ...
# 2548396  The Cloverfield Paradox  2018      102    5.6         37
# 1825683            Black Panther  2018      134    7.4         88
# 2873282              Red Sparrow  2018      140    6.6         53
# 5164214            Ocean's Eight  2018      110    6.3         61
# 3606756            Incredibles 2  2018      118    8.0         80
# 1270797                    Venom  2018      112    7.1         35
# 5164432              Love, Simon  2018      110    7.7         72
# 6644200            A Quiet Place  2018       90    7.7         82
# 1677720         Ready Player One  2018      140    7.6         64
# 7784604               Hereditary  2018      127    7.3         87
#
#                                                       opis
# id
# 12349    Six unemployed steel workers form a male strip...
# 13442    An assassin teams up with a woman to help her ...
# 15864    A young woman, after witnessing her parents' m...
# 17925    A group of teenagers look to save their town f...
# 17136    In a futuristic city sharply divided between t...
# 22100    Robbie, a singer, and Julia, a waitress, are b...
# 21749    The comic "Bluntman and Chronic" is based on r...
# 24216    A film crew goes to a tropical island for an e...
# 25316    A spoiled heiress running away from her family...
# 27977    The Tramp struggles to live in modern industri...
# ...                                                    ...
# 2548396  Orbiting a planet on the brink of war, scienti...
# 1825683  T'Challa, heir to the hidden but advanced king...
# 2873282  Ballerina Dominika Egorova is recruited to 'Sp...
# 5164214  Debbie Ocean gathers an all-female crew to att...
# 3606756  Bob Parr (Mr. Incredible) is left to care for ...
# 1270797  When Eddie Brock acquires the powers of a symb...
# 5164432  Simon Spier keeps a huge secret from his famil...
# 6644200  In a post-apocalyptic world, a family is force...
# 1677720  When the creator of a virtual reality world ca...
# 7784604  After the family matriarch passes away, a grie...
#
# [2396 rows x 6 columns]

# %%
# najprej uredi padajoče po oceni, pri vsaki oceni pa še naraščajoče po letu
filmi.sort_values(['ocena', 'leto'], ascending=[False, True])
# Out:
#                                                 naslov  leto  dolzina  ocena  \
# id
# 5813916                                The Mountain II  2016      135    9.4
# 111161                        The Shawshank Redemption  1994      142    9.3
# 68646                                    The Godfather  1972      175    9.2
# 71562                           The Godfather: Part II  1974      202    9.0
# 468569                                 The Dark Knight  2008      152    9.0
# 50083                                     12 Angry Men  1957       96    8.9
# 60196                   The Good, the Bad and the Ugly  1966      178    8.9
# 108052                                Schindler's List  1993      195    8.9
# 110912                                    Pulp Fiction  1994      154    8.9
# 167260   The Lord of the Rings: The Return of the King  2003      201    8.9
# ...                                                ...   ...      ...    ...
# 120179                         Speed 2: Cruise Control  1997      121    3.8
# 118688                                  Batman & Robin  1997      125    3.7
# 368226                                        The Room  2003       99    3.6
# 327554                                        Catwoman  2004      104    3.3
# 810913                                   Jack and Jill  2011       91    3.3
# 1073498                              Meet the Spartans  2008       86    2.7
# 1098327                          Dragonball: Evolution  2009       85    2.6
# 185183                               Battlefield Earth  2000      118    2.4
# 799949                                      Epic Movie  2007       86    2.3
# 1213644                                 Disaster Movie  2008       87    1.9
#
#          metascore                                               opis
# id
# 5813916         69  A drama based on a Texas congressman Charlie W...
# 111161          80  Two imprisoned men bond over a number of years...
# 68646          100  The aging patriarch of an organized crime dyna...
# 71562           90  The early life and career of Vito Corleone in ...
# 468569          84  When the menace known as the Joker emerges fro...
# 50083           96  A jury holdout attempts to prevent a miscarria...
# 60196           90  A bounty hunting scam joins two men in an unea...
# 108052          93  In German-occupied Poland during World War II,...
# 110912          94  The lives of two mob hitmen, a boxer, a gangst...
# 167260          94  Gandalf and Aragorn lead the World of Men agai...
# ...            ...                                                ...
# 120179          23  A computer hacker breaks into the computer sys...
# 118688          28  Batman and Robin try to keep their relationshi...
# 368226           9  Johnny is a successful banker who lives happil...
# 327554          27  A shy woman, endowed with the speed, reflexes,...
# 810913          23  Family guy Jack Sadelstein prepares for the an...
# 1073498          9  The heroic Spartan king Leonidas, armed with n...
# 1098327         45  The young warrior Son Goku sets out on a quest...
# 185183           9  It's the year 3000 A.D.; the Earth is lost to ...
# 799949          17  A comedic satire of films that are large in sc...
# 1213644         15  Over the course of one evening, an unsuspectin...
#
# [2396 rows x 6 columns]

# %% [markdown]
# ### Skupine

# %% [markdown]
# Z metodo `.groupby` ustvarimo razpredelnico posebne vrste, v katerem so vrstice združene glede na skupno lastnost.

# %%
filmi_po_letih = filmi.groupby('leto')

# %%
# povprečna ocena vsakega leta
filmi_po_letih['ocena'].mean()
# Out:
# leto
# 1921    8.300000
# 1922    8.000000
# 1925    8.200000
# 1926    8.200000
# 1927    8.300000
# 1931    8.450000
# 1933    7.900000
# 1934    8.100000
# 1936    8.500000
# 1937    7.600000
#           ...
# 2009    6.752830
# 2010    6.717117
# 2011    6.712605
# 2012    6.825243
# 2013    6.794400
# 2014    6.892857
# 2015    6.871429
# 2016    6.901942
# 2017    6.938806
# 2018    7.040909
# Name: ocena, Length: 87, dtype: float64

# %%
# če želimo, lahko združujemo tudi po izračunanih lastnostih
filmi['petletka'] = 5 * (filmi.leto // 5)
filmi
# Out:
#                                                     naslov  leto  dolzina  \
# id
# 449467                                             Babilon  2006      143
# 110148   Interview with the Vampire: The Vampire Chroni...  1994      123
# 489099                                              Jumper  2008       88
# 1397280                                       Ugrabljena 2  2012       92
# 1245526                                                RED  2010      111
# 87843                          Once Upon a Time in America  1984      229
# 472043                                          Apocalypto  2006      139
# 379786                                            Serenity  2005      119
# 120663                                      Eyes Wide Shut  1999      159
# 381849                                        3:10 to Yuma  2007      122
# ...                                                    ...   ...      ...
# 1659337                    The Perks of Being a Wallflower  2012      103
# 425112                                            Hot Fuzz  2007      121
# 289879                                The Butterfly Effect  2004      113
# 3460252                                  The Hateful Eight  2015      187
# 1800241                                    American Hustle  2013      138
# 96874                           Back to the Future Part II  1989      108
# 242653                              The Matrix Revolutions  2003      129
# 99487                                  Edward Scissorhands  1990      105
# 2911666                                          John Wick  2014      101
# 356910                                    Mr. & Mrs. Smith  2005      120
#
#          ocena  metascore                                               opis  \
# id
# 449467     7.5         69  Tragedy strikes a married couple on vacation i...
# 110148     7.6         59  A vampire tells his epic life story: love, bet...
# 489099     6.1         35  A teenager with teleportation abilities sudden...
# 1397280    6.3         45  In Istanbul, retired CIA operative Bryan Mills...
# 1245526    7.1         60  When his peaceful life is threatened by a high...
# 87843      8.4         77  An epic mosaic of interrelated characters in s...
# 472043     7.8         68  As the Mayan kingdom faces its decline, a youn...
# 379786     7.9         74  The crew of the ship Serenity try to evade an ...
# 120663     7.4         68  A New York City doctor, who is married to an a...
# 381849     7.7         76  A small-time rancher agrees to hold a captured...
# ...        ...        ...                                                ...
# 1659337    8.0         67  An introvert freshman is taken under the wings...
# 425112     7.9         81  A skilled London police officer is transferred...
# 289879     7.7         30  Evan Treborn suffers blackouts during signific...
# 3460252    7.8         68  In the dead of a Wyoming winter, a bounty hunt...
# 1800241    7.3         90  A con man, Irving Rosenfeld, along with his se...
# 96874      7.8         57  After visiting 2015, Marty McFly must repeat h...
# 242653     6.7         47  The human city of Zion defends itself against ...
# 99487      7.9         74  A gentle man, with scissors for hands, is brou...
# 2911666    7.3         68  An ex-hitman comes out of retirement to track ...
# 356910     6.5         55  A bored married couple is surprised to learn t...
#
#          petletka
# id
# 449467       2005
# 110148       1990
# 489099       2005
# 1397280      2010
# 1245526      2010
# 87843        1980
# 472043       2005
# 379786       2005
# 120663       1995
# 381849       2005
# ...           ...
# 1659337      2010
# 425112       2005
# 289879       2000
# 3460252      2015
# 1800241      2010
# 96874        1985
# 242653       2000
# 99487        1990
# 2911666      2010
# 356910       2005
#
# [2396 rows x 7 columns]

# %%
filmi_po_petletkah = filmi.groupby('petletka')

# %% [markdown]
# Preštejemo, koliko filmov je bilo v vsakem petletki. Pri večini stolpcev dobimo iste številke, ker imamo v vsakem stolpcu enako vnosov. Če kje kakšen podatek manjkal, je številka manjša.

# %%
filmi_po_petletkah.count()
# Out:
#           naslov  leto  dolzina  ocena  metascore  opis
# petletka
# 1920           2     2        2      2          2     2
# 1925           3     3        3      3          3     3
# 1930           4     4        4      4          4     4
# 1935           5     5        5      5          5     5
# 1940          10    10       10     10         10    10
# 1945           6     6        6      6          6     6
# 1950          16    16       16     16         16    16
# 1955          18    18       18     18         18    18
# 1960          23    23       23     23         23    23
# 1965          19    19       19     19         19    19
# 1970          24    24       24     24         24    24
# 1975          37    37       37     37         37    37
# 1980          60    60       60     60         60    60
# 1985          96    96       96     96         96    96
# 1990         126   126      126    126        126   126
# 1995         254   254      254    254        254   254
# 2000         360   360      360    360        360   360
# 2005         501   501      501    501        501   501
# 2010         556   556      556    556        556   556
# 2015         276   276      276    276        276   276

# %% [markdown]
# Če želimo dobiti le število članov posamezne skupine, uporabimo metodo `.size()`. V tem primeru dobimo le stolpec, ne razpredelnice.

# %%
filmi_po_petletkah.size()
# Out:
# petletka
# 1920      2
# 1925      3
# 1930      4
# 1935      5
# 1940     10
# 1945      6
# 1950     16
# 1955     18
# 1960     23
# 1965     19
# 1970     24
# 1975     37
# 1980     60
# 1985     96
# 1990    126
# 1995    254
# 2000    360
# 2005    501
# 2010    556
# 2015    276
# dtype: int64

# %% [markdown]
# Pogledamo povprečja vsake petletke. Dobimo povprečno leto, povprečno dolžino in oceno. Povprečnega naslova ne dobimo, ker se ga ne da izračunati, zato ustreznega stolpca ni.

# %%
filmi_po_petletkah.mean()
# Out:
#                  leto     dolzina     ocena  metascore
# petletka
# 1920      1921.500000   74.500000  8.150000  51.500000
# 1925      1926.000000  105.000000  8.233333  58.000000
# 1930      1932.250000   97.750000  8.225000  71.750000
# 1935      1938.000000  127.800000  8.100000  92.200000
# 1940      1941.000000  105.900000  7.980000  65.800000
# 1945      1947.166667  108.833333  8.233333  84.833333
# 1950      1951.875000  108.000000  8.062500  86.250000
# 1955      1957.222222  110.944444  8.105556  83.111111
# 1960      1962.000000  129.304348  7.908696  76.086957
# 1965      1966.894737  130.263158  7.905263  76.473684
# 1970      1972.625000  117.416667  7.791667  75.958333
# 1975      1977.351351  119.378378  7.740541  74.810811
# 1980      1982.483333  114.233333  7.546667  66.200000
# 1985      1987.239583  110.895833  7.354167  62.541667
# 1990      1992.111111  117.515873  7.282540  63.365079
# 1995      1997.236220  115.043307  6.965354  60.488189
# 2000      2002.183333  113.894444  6.873056  58.130556
# 2005      2007.097804  111.499002  6.793014  57.894212
# 2010      2011.964029  112.232014  6.784532  58.332734
# 2015      2016.097826  116.789855  6.912681  61.163043

# %% [markdown]
# ## Risanje grafov

# %%
# vključimo risanje grafov (če stvari začnejo delati počasneje, izklopimo možnost inline)
# %matplotlib inline

# %% [markdown]
# Običajen graf dobimo z metodo `plot`. Uporabljamo ga, kadar želimo prikazati spreminjanje vrednosti v odvisnosti od zvezne spremenljivke

# %% [markdown]
# Naša hipoteza je, da so zlata leta filma mimo. Graf to potrjuje.

# %%
filmi[filmi['ocena'] > 8.5].groupby('petletka').size().plot()

# %% [markdown]
# Razsevni diagram dobimo z metodo `plot.scatter`. Uporabljamo ga, če želimo ugotoviti povezavo med dvema spremenljivkama.

# %%
filmi.plot.scatter('metascore', 'ocena')

# %% [markdown]
# Stolpčni diagram dobimo z metodo `plot.bar`. Uporabljamo ga, če želimo primerjati vrednosti pri diskretnih (običajno kategoričnih) spremenljivkah. Pogosto je koristno, da graf uredimo po vrednostih.

# %%
filmi.sort_values('ocena', ascending=True).head(20).plot.bar(x='naslov', y='ocena')

# %% [markdown]
# ## Stikanje podatkov

# %%
osebe = pd.read_csv('csv-datoteke/osebe.csv', index_col='id')
vloge = pd.read_csv('csv-datoteke/vloge.csv')
zanri = pd.read_csv('csv-datoteke/zanri.csv')

# %% [markdown]
# Razpredelnice združujemo s funkcijo `merge`, ki vrne razpredelnico vnosov iz obeh tabel, pri katerih se vsi istoimenski podatki ujemajo.

# %%
vloge[vloge['film'] == 97576]

# %%
zanri[zanri['film'] == 97576]

# %%
pd.merge(vloge, zanri)

# %% [markdown]
# Poglejmo, katera oseba je nastopala v največ komedijah.

# %%
zanri_vlog = pd.merge(vloge, zanri)
zanri_vlog[
    zanri_vlog['zanr'] == 'Comedy'
].groupby(
    'vloga'
).size().sort_values(ascending=False)

# %% [markdown]
# ### Povprečne ocene žanrov

# %% [markdown]
# V osnovi vsebuje združena razpredelnica le tiste vnose, ki se pojavijo v obeh tabelah. Temu principu pravimo notranji stik (_inner join_). Lahko pa se odločimo, da izberemo tudi tiste vnose, ki imajo podatke le v levi tabeli (_left join_), le v desni tabeli (_right join_) ali v vsaj eni tabeli (_outer join_). Če v eni tabeli ni vnosov, bodo v združeni tabeli označene manjkajoče vrednosti. Ker smo v našem primeru podatke jemali iz IMDBja, kjer so za vsak film določeni tako žanri kot vloge, do razlik ne pride.

# %% [markdown]
# Če želimo razpredelnice združevati po ključih, namesto `merge` uporabimo `join` (ki v ozadju uporablja `merge`).

# %%
zanri.join(filmi, on='film')

# %% [markdown]
# Enako bi lahko dosegli s funkcijo `merge`, vendar bi poprej razpredelnici `filmi` morali stolpec `id` iz indeksa pretvoriti v običajni stolpec. Ker razpredelnici nimata enako poimenovanih stolpcev, moramo posebej povedati, katere leve stolpce združimo s katerimi desnimi.

# %%
pd.merge(zanri, filmi.reset_index(), left_on='film', right_on='id')

# %% [markdown]
# Z združeno tabelo lahko izračunamo tudi povprečno oceno glede na žanr.

# %%
zanri.join(
    filmi.ocena, on='film'
).groupby(
    'zanr'
).mean(
).sort_values(
    'ocena', ascending=False
)['ocena']

# %% [markdown]
# Poglejmo, kako popularni so bili posamezni žanri skozi desetletja. Najprej vsakemu filmu dodajmo še stolpec z desetletjem.

# %%
filmi['desetletje'] = 10 * (filmi['leto'] // 10)

# %% [markdown]
# Nato poglejmo, koliko je bilo filmov posameznega žanra v vsakem desetletju.

# %%
zastopanost_zanrov = zanri.join(
    filmi, on='film'
).groupby(
    ['desetletje', 'zanr']
).size()
zastopanost_zanrov

# %% [markdown]
# Ker smo združevali po več lastnostih, smo dobili stolpec s hierarhičnim indeksom. Tega lahko pretvorimo v matriko z metodo `.unstack`.

# %%
matrika_zastopanosti = zastopanost_zanrov.unstack()
matrika_zastopanosti

# %% [markdown]
# Ker nas zanima le popularnost žanra v posameznem desetletju, želimo za vsak stolpec izračunati razmerje števila filmov danega žanra glede na število vseh filmov. To storimo s pomočjo metode `.apply`, ki v dani razpredelnici dano funkcijo uporabi na vsaki vrstici ali stolpcu (če dodamo možnost `axis=1`). Če bi želeli funkcijo uporabiti na vsakem elementu stolpca, bi namesto `.apply` uporabili `.map`.

# %%
matrika_popularnosti = matrika_zastopanosti.apply(lambda st: st / st.sum(), axis=1)
matrika_popularnosti

# %%
matrika_popularnosti.plot(kind='area')

# %% [markdown]
# Zgornji graf je čisto nepregleden. Omejimo se le na 10 najpopularnejših žanrov.

# %%
najpopularnejsi_zanri = zanri.groupby('zanr').size().sort_values(ascending=False)

# %%
najpopularnejsi_zanri

# %% [markdown]
# Prve žanr ignorirajmo, ker je precej generičen.

# %%
zanimivi_zanri = najpopularnejsi_zanri[1:11]

# %%
zanri[zanri['zanr'].isin(list(zanimivi_zanri.index))]
zastopanost_zanrov = zanri[zanri['zanr'].isin(list(zanimivi_zanri.index))].join(
    filmi, on='film'
).groupby(
    ['desetletje', 'zanr']
).size()
matrika_zastopanosti = zastopanost_zanrov.unstack()
matrika_popularnosti = matrika_zastopanosti.apply(lambda st: st / st.sum(), axis=1)
matrika_popularnosti.plot(kind='area')
