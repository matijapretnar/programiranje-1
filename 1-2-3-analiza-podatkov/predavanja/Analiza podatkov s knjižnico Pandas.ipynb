# %% [markdown]
# # Analiza podatkov s knjižnico Pandas
#
# Spodaj je pregled najosnovnejših metod, ki jih ponuja knjižnica Pandas. Vsaka od naštetih metod ponuja še cel kup dodatnih možnosti, ki so natančno opisane v [uradni dokumentaciji](http://pandas.pydata.org/pandas-docs/stable/). Z branjem dokumentacije se vam seveda najbolj splača začeti pri [uvodih](http://pandas.pydata.org/pandas-docs/stable/tutorials.html).

# %% [markdown]
# ### Predpriprava

# %%
# naložimo paket
import pandas as pd

# naložimo razpredelnico, s katero bomo delali
serije = pd.read_csv('serije.csv', index_col='id')

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 20 vrstic
pd.options.display.max_rows = 20

# %% [markdown]
# ## Delo z razpredelnicami

# %% [markdown]
# ### Osnovni izbori elementov razpredelnic

# %% [markdown]
# Z metodo `.head(n=5)` pogledamo prvih `n`, z metodo `.tail(n=5)` pa zadnjih `n` vrstic razpredelnice.

# %%
serije.head(10)
# Out:
#                                   ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 944947                 Igra prestolov    NaN          2011         NaN    9.5
# 903747                     Kriva pota    NaN          2008      2013.0    9.5
# 1520211                  Zivi mrtveci    NaN          2010         NaN    8.5
# 1475582                      Sherlock    NaN          2010         NaN    9.2
# 898266                 Veliki pokovci    NaN          2007         NaN    8.3
# 108778                     Prijatelji    NaN          1994      2004.0    8.9
# 773262                         Dexter    NaN          2006      2013.0    8.7
# 460649   Kako sem spoznal vajino mamo    NaN          2005      2014.0    8.4
# 411008               Skrivnostni otok    NaN          2004      2010.0    8.4
# 455275                  Beg iz zapora    NaN          2005         NaN    8.4
#
#                                                       opis  stevilo_glasov  \
# id
# 944947   Nine noble families fight for control over the...         1241629
# 903747   A high school chemistry teacher diagnosed with...         1023499
# 1520211  Sheriff Deputy Rick Grimes wakes up from a com...          710538
# 1475582  A modern update finds the famous sleuth and hi...          602975
# 898266   A woman who moves into an apartment across the...          579154
# 108778   Follows the personal and professional lives of...          552940
# 773262   By day, mild-mannered Dexter is a blood-spatte...          545745
# 460649   A father recounts to his children, through a s...          491728
# 411008   The survivors of a plane crash are forced to w...          417078
# 455275   Due to a political conspiracy, an innocent man...          393278
#
#          dolzina
# id
# 944947      57.0
# 903747      49.0
# 1520211     44.0
# 1475582     88.0
# 898266      22.0
# 108778      22.0
# 773262      53.0
# 460649      22.0
# 411008      44.0
# 455275      44.0

# %%
serije.tail()
# Out:
#                                   ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 264244   Il était une fois... l'homme    NaN          1978         NaN    8.1
# 202741                   The Man Show    NaN          1999      2014.0    6.8
# 377253               Rosemary & Thyme    NaN          2003      2006.0    7.7
# 112225                       Wishbone    NaN          1995      1998.0    8.4
# 5537534                          Ajin    NaN          2016         NaN    7.8
#
#                                                       opis  stevilo_glasov  \
# id
# 264244   A comprehensive animated survey of the evoluti...            2668
# 202741   A comedic talk show geared toward men, and the...            2662
# 377253   Set amongst the stunning gardens of Europe, Ro...            2656
# 112225   An intelligent and witty dog imagines himself ...            2656
# 5537534  17 years ago, immortals first appeared on the ...            2646
#
#          dolzina
# id
# 264244      25.0
# 202741      30.0
# 377253      60.0
# 112225      30.0
# 5537534     24.0

# %% [markdown]
# Z indeksiranjem razpredelnice dostopamo do posameznih stolpcev. Če želimo več stolpcev, moramo za indeks podati seznam vseh oznak. Z rezinami pa dostopamo do izbranih vrstic.

# %%
serije['ime']
# Out:
# id
# 944947                    Igra prestolov
# 903747                        Kriva pota
# 1520211                     Zivi mrtveci
# 1475582                         Sherlock
# 898266                    Veliki pokovci
# 108778                        Prijatelji
# 773262                            Dexter
# 460649      Kako sem spoznal vajino mamo
# 411008                  Skrivnostni otok
# 455275                     Beg iz zapora
#                        ...
# 83479                      Silver Spoons
# 2817246    Girlfriends' Guide to Divorce
# 73955                              Alice
# 262151                   Bob the Builder
# 94511                Mission: Impossible
# 264244      Il était une fois... l'homme
# 202741                      The Man Show
# 377253                  Rosemary & Thyme
# 112225                          Wishbone
# 5537534                             Ajin
# Name: ime, Length: 2000, dtype: object

# %%
serije[['ime', 'ocena']]
# Out:
#                                    ime  ocena
# id
# 944947                  Igra prestolov    9.5
# 903747                      Kriva pota    9.5
# 1520211                   Zivi mrtveci    8.5
# 1475582                       Sherlock    9.2
# 898266                  Veliki pokovci    8.3
# 108778                      Prijatelji    8.9
# 773262                          Dexter    8.7
# 460649    Kako sem spoznal vajino mamo    8.4
# 411008                Skrivnostni otok    8.4
# 455275                   Beg iz zapora    8.4
# ...                                ...    ...
# 83479                    Silver Spoons    6.1
# 2817246  Girlfriends' Guide to Divorce    6.9
# 73955                            Alice    6.9
# 262151                 Bob the Builder    5.4
# 94511              Mission: Impossible    7.6
# 264244    Il était une fois... l'homme    8.1
# 202741                    The Man Show    6.8
# 377253                Rosemary & Thyme    7.7
# 112225                        Wishbone    8.4
# 5537534                           Ajin    7.8
#
# [2000 rows x 2 columns]

# %%
serije[120:125]
# Out:
#                                  ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 2575988               Silicon Valley    NaN          2014         NaN    8.6
# 2234222                 Orphan Black    NaN          2013      2017.0    8.4
# 3743822        Fear the Walking Dead    NaN          2015         NaN    7.0
# 3205802  How to Get Away with Murder    NaN          2014         NaN    8.2
# 1548850                      Misfits    NaN          2009      2013.0    8.3
#
#                                                       opis  stevilo_glasov  \
# id
# 2575988  Follows the struggle of Richard Hendricks, a s...           82743
# 2234222  A streetwise hustler is pulled into a compelli...           82652
# 3743822  A Walking Dead spin-off, set in Los Angeles, f...           82203
# 3205802  A group of ambitious law students and their br...           80442
# 1548850  A group of young offenders doing community ser...           80069
#
#          dolzina
# id
# 2575988     28.0
# 2234222     44.0
# 3743822     44.0
# 3205802     43.0
# 1548850     60.0

# %% [markdown]
# Do vrednosti z indeksom `i` dostopamo z `.iloc[i]`, do tiste s ključem `k` pa z `.loc[k]`.

# %%
serije.iloc[120]
# Out:
# ime                                                  Silicon Valley
# oznaka                                                          NaN
# leto_zacetka                                                   2014
# leto_konca                                                      NaN
# ocena                                                           8.6
# opis              Follows the struggle of Richard Hendricks, a s...
# stevilo_glasov                                                82743
# dolzina                                                          28
# Name: 2575988, dtype: object

# %%
serije.loc[303461]
# Out:
# ime                                                         Firefly
# oznaka                                                          NaN
# leto_zacetka                                                   2002
# leto_konca                                                     2003
# ocena                                                           9.1
# opis              Five hundred years in the future, a renegade c...
# stevilo_glasov                                               205968
# dolzina                                                          44
# Name: 303461, dtype: object

# %% [markdown]
# ### Filtriranje in urejanje

# %% [markdown]
# Izbor določenih vrstic razpredelnice naredimo tako, da za indeks podamo stolpec logičnih vrednosti, ki ga dobimo z običajnimi operacijami. V vrnjeni razpredelnici bodo ostale vrstice, pri katerih je v stolpcu vrednost `True`.

# %%
serije.ocena >= 8
# Out:
# id
# 944947      True
# 903747      True
# 1520211     True
# 1475582     True
# 898266      True
# 108778      True
# 773262      True
# 460649      True
# 411008      True
# 455275      True
#            ...
# 83479      False
# 2817246    False
# 73955      False
# 262151     False
# 94511      False
# 264244      True
# 202741     False
# 377253     False
# 112225      True
# 5537534    False
# Name: ocena, Length: 2000, dtype: bool

# %%
serije[serije.ocena >= 8]
# Out:
#                                   ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 944947                 Igra prestolov    NaN          2011         NaN    9.5
# 903747                     Kriva pota    NaN          2008      2013.0    9.5
# 1520211                  Zivi mrtveci    NaN          2010         NaN    8.5
# 1475582                      Sherlock    NaN          2010         NaN    9.2
# 898266                 Veliki pokovci    NaN          2007         NaN    8.3
# 108778                     Prijatelji    NaN          1994      2004.0    8.9
# 773262                         Dexter    NaN          2006      2013.0    8.7
# 460649   Kako sem spoznal vajino mamo    NaN          2005      2014.0    8.4
# 411008               Skrivnostni otok    NaN          2004      2010.0    8.4
# 455275                  Beg iz zapora    NaN          2005         NaN    8.4
# ...                               ...    ...           ...         ...    ...
# 4565380                         Fauda    NaN          2015         NaN    8.4
# 4680240               Club de Cuervos    NaN          2015         NaN    8.1
# 191714                 Otvorena vrata    NaN          1994         NaN    9.2
# 2955402                        Velvet    NaN          2013      2016.0    8.2
# 2240991              A Touch of Cloth    NaN          2012         NaN    8.0
# 2348803              Kuroko no basuke    NaN          2012      2015.0    8.4
# 6392930                   Swar Shuaib    NaN          2014         NaN    9.1
# 965547        Slam Dunk: Suramu danku    NaN          1993      1996.0    8.7
# 264244   Il était une fois... l'homme    NaN          1978         NaN    8.1
# 112225                       Wishbone    NaN          1995      1998.0    8.4
#
#                                                       opis  stevilo_glasov  \
# id
# 944947   Nine noble families fight for control over the...         1241629
# 903747   A high school chemistry teacher diagnosed with...         1023499
# 1520211  Sheriff Deputy Rick Grimes wakes up from a com...          710538
# 1475582  A modern update finds the famous sleuth and hi...          602975
# 898266   A woman who moves into an apartment across the...          579154
# 108778   Follows the personal and professional lives of...          552940
# 773262   By day, mild-mannered Dexter is a blood-spatte...          545745
# 460649   A father recounts to his children, through a s...          491728
# 411008   The survivors of a plane crash are forced to w...          417078
# 455275   Due to a political conspiracy, an innocent man...          393278
# ...                                                    ...             ...
# 4565380  "Fauda" (Arabic for 'Chaos') depicts the two-s...            2753
# 4680240  When the patriarch of a prominent family dies,...            2748
# 191714   Katarina Andjelic, nicknamed "Cakana", lives w...            2742
# 2955402  Alberto (Miguel Ángel Silvestre) has been left...            2731
# 2240991  DCI Jack Cloth and DC Anne Oldman are paired t...            2729
# 2348803  The Teiko Middle School Basketball Team. The s...            2727
# 6392930  Swar Shuaib is a comedy talk show with a stron...            2707
# 965547   About Sakuragi Hanamichi, a freshman of Shohok...            2688
# 264244   A comprehensive animated survey of the evoluti...            2668
# 112225   An intelligent and witty dog imagines himself ...            2656
#
#          dolzina
# id
# 944947      57.0
# 903747      49.0
# 1520211     44.0
# 1475582     88.0
# 898266      22.0
# 108778      22.0
# 773262      53.0
# 460649      22.0
# 411008      44.0
# 455275      44.0
# ...          ...
# 4565380     60.0
# 4680240     40.0
# 191714      30.0
# 2955402     43.0
# 2240991      NaN
# 2348803      NaN
# 6392930      NaN
# 965547      22.0
# 264244      25.0
# 112225      30.0
#
# [760 rows x 8 columns]

# %%
serije[(serije.leto_zacetka > 2010) & (serije.ocena >= 8.5)]
# Out:
#                                 ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 944947               Igra prestolov    NaN          2011         NaN    9.5
# 1856010              House of Cards    NaN          2013         NaN    9.0
# 2356777              Pravi detektiv    NaN          2014         NaN    9.0
# 4574334             Stranger Things    NaN          2016         NaN    8.9
# 1632701        Nepremagljivi dvojec    NaN          2011         NaN    8.6
# 3322312                   Daredevil    NaN          2015         NaN    8.7
# 2306299                     Vikings    NaN          2013         NaN    8.6
# 4158110                   Mr. Robot    NaN          2015         NaN    8.6
# 475784                    Westworld    NaN          2016         NaN    9.0
# 2802850                       Fargo    NaN          2014         NaN    9.0
# ...                             ...    ...           ...         ...    ...
# 1554369        The Booth at the End    NaN          2011         NaN    8.5
# 2147995          Der Tatortreiniger    NaN          2011         NaN    8.6
# 5863126               Last Chance U    NaN          2016         NaN    8.5
# 2610260             Honest Trailers    NaN          2012         NaN    8.7
# 2930610                     Kukhnya    NaN          2012         NaN    8.8
# 4925000         Tae-yang-eui hoo-ye    NaN          2016         NaN    8.6
# 5099020                   Aranyélet    NaN          2015         NaN    9.0
# 5697728  Kuch Rang Pyar Ke Aise Bhi    NaN          2016      2017.0    9.3
# 2392261   The Lizzie Bennet Diaries    NaN          2012         NaN    8.8
# 6392930                 Swar Shuaib    NaN          2014         NaN    9.1
#
#                                                       opis  stevilo_glasov  \
# id
# 944947   Nine noble families fight for control over the...         1241629
# 1856010  A Congressman works with his equally conniving...          378257
# 2356777  Seasonal anthology series in which police inve...          373052
# 4574334  When a young boy disappears, his mother, a pol...          346893
# 1632701  On the run from a drug deal gone bad, Mike Ros...          282707
# 3322312  Matt Murdock, with his other senses superhuman...          269245
# 2306299  The world of the Vikings is brought to life th...          258947
# 4158110  Follows Elliot, a young programmer working as ...          232697
# 475784   Set at the intersection of the near future and...          220165
# 2802850  Various chronicles of deception, intrigue and ...          219707
# ...                                                    ...             ...
# 1554369  Everyone wants something. There is a mysteriou...            3355
# 2147995  The bizarre everyday adventures of Heiko "Scho...            3332
# 5863126  "Last Chance U" follows a group of young men t...            3330
# 2610260  In this web series the Screen Junkies crew pic...            3054
# 2930610  Maksim "Max" Lavrov wants to become a great ch...            2886
# 4925000  A love story develops between Captain Yoo Shi ...            2873
# 5099020  A corrupt businessman and family man attempts ...            2867
# 5697728  Kuch Rang Pyar Ke Aise Bhi is a mature love st...            2783
# 2392261  A modern day retelling of Pride and Prejudice,...            2769
# 6392930  Swar Shuaib is a comedy talk show with a stron...            2707
#
#          dolzina
# id
# 944947      57.0
# 1856010     51.0
# 2356777     55.0
# 4574334     55.0
# 1632701     44.0
# 3322312     54.0
# 2306299     44.0
# 4158110     49.0
# 475784      60.0
# 2802850     53.0
# ...          ...
# 1554369     30.0
# 2147995     26.0
# 5863126     55.0
# 2610260      5.0
# 2930610      NaN
# 4925000     60.0
# 5099020     60.0
# 5697728     22.0
# 2392261      3.0
# 6392930      NaN
#
# [98 rows x 8 columns]

# %% [markdown]
# Razpredelnico urejamo z metodo `.sort_values`, ki ji podamo ime ali seznam imen stolpcev, po katerih želimo urejati. Po želji lahko tudi povemo, kateri stolpci naj bodo urejeni naraščajoče in kateri padajoče.

# %%
serije.sort_values('leto_zacetka')
# Out:
#                                               ime oznaka  leto_zacetka  \
# id
# 43208                               Rad imam Lucy    NaN          1951
# 47736                                    Gunsmoke    NaN          1955
# 42114                            The Honeymooners    NaN          1955
# 47708                   Alfred Hitchcock Presents    NaN          1955
# 184175                  The Woody Woodpecker Show    NaN          1957
# 50051                                 Perry Mason    NaN          1957
# 50032                          Leave It to Beaver    NaN          1957
# 52451                                     Bonanza    NaN          1959
# 52520                             Obmocje somraka    NaN          1959
# 53502                             The Flintstones    NaN          1960
# ...                                           ...    ...           ...
# 6478318                                     Masum    NaN          2017
# 5031234                           Time After Time    NaN          2017
# 5503718                                     Gypsy    NaN          2017
# 5669272  Wet Hot American Summer: Ten Years Later    NaN          2017
# 5592230                 The Blacklist: Redemption    NaN          2017
# 5707802                         Dear White People    NaN          2017
# 5565334                      Friends from College    NaN          2017
# 4998350                                 The Deuce    NaN          2017
# 5580540                        Santa Clarita Diet    NaN          2017
# 6170874                                 Salvation    NaN          2017
#
#          leto_konca  ocena                                               opis  \
# id
# 43208        1957.0    8.4  A daffy woman constantly strives to become a s...
# 47736        1975.0    8.0  Marshal Matt Dillon keeps the peace in the rou...
# 42114        1956.0    8.6  A bus driver and his sewer worker friend strug...
# 47708        1962.0    8.6  Series of unrelated short stories covering ele...
# 184175          NaN    7.1  A TV show featuring funny old and new shorts s...
# 50051        1966.0    8.2  The cases of a master criminal defense attorne...
# 50032        1963.0    7.6  The misadventures of a suburban boy, family an...
# 52451        1973.0    7.3  The adventures of Ben Cartwright and his sons ...
# 52520        1964.0    9.0  Ordinary people find themselves in extraordina...
# 53502        1966.0    7.5  The misadventures of two modern-day Stone Age ...
# ...             ...    ...                                                ...
# 6478318         NaN    9.2  Cevdet (Haluk Bilginer), a retired commissione...
# 5031234         NaN    6.8  The adventures of young H.G. Wells and his tim...
# 5503718         NaN    7.0  Therapist Jean Holloway becomes too immersed i...
# 5669272         NaN    7.1  The campers and counselors of Camp Firewood me...
# 5592230         NaN    7.2  Covert operative Tom Keen joins forces with Su...
# 5707802         NaN    6.4  At a predominantly white Ivy League college, a...
# 5565334         NaN    6.7  A group of friends from Harvard are facing dow...
# 4998350         NaN    8.3  A look at life in New York City during the 197...
# 5580540         NaN    7.7  Sheila and Joel are married real estate agents...
# 6170874         NaN    6.9  An MIT grad student and a tech superstar bring...
#
#          stevilo_glasov  dolzina
# id
# 43208             18807     30.0
# 47736              3734     60.0
# 42114              3750     30.0
# 47708             10949     25.0
# 184175             3193     30.0
# 50051              3560     60.0
# 50032              5039     30.0
# 52451              6107     49.0
# 52520             50997     51.0
# 53502             26501     30.0
# ...                 ...      ...
# 6478318            3826     60.0
# 5031234            2747     60.0
# 5503718            7392     51.0
# 5669272            3327     30.0
# 5592230            4110     43.0
# 5707802           11247     30.0
# 5565334            7297     30.0
# 4998350            3306     60.0
# 5580540           20855     30.0
# 6170874            4486     43.0
#
# [2000 rows x 8 columns]

# %%
# najprej uredi padajoče po oceni, pri vsaki oceni pa še naraščajoče po letu
serije.sort_values(['ocena', 'leto_zacetka'], ascending=[False, True])
# Out:
#                                      ime oznaka  leto_zacetka  leto_konca  \
# id
# 4202274            The Filthy Frank Show    NaN          2011         NaN
# 6111552                      Content Cop    NaN          2015         NaN
# 903747                        Kriva pota    NaN          2008      2013.0
# 944947                    Igra prestolov    NaN          2011         NaN
# 158417                        Mahabharat    NaN          1988      1990.0
# 5851616                     Tash ma Tash    NaN          1992      2010.0
# 2861424                   Rick and Morty    NaN          2013         NaN
# 306414                    Skrivna naveza    NaN          2002      2008.0
# 4742876                     TVF Pitchers    NaN          2015         NaN
# 5697728       Kuch Rang Pyar Ke Aise Bhi    NaN          2016      2017.0
# ...                                  ...    ...           ...         ...
# 1491299      Kourtney & Khloé Take Miami    NaN          2009         NaN
# 348894                  The Bachelorette    NaN          2003         NaN
# 468999                    Mind of Mencia    NaN          2005         NaN
# 313038                      The Bachelor    NaN          2002         NaN
# 123366                          The View    NaN          1997         NaN
# 1086761  Keeping Up with the Kardashians    NaN          2007         NaN
# 2288050         Here Comes Honey Boo Boo    NaN          2012      2017.0
# 175383                      Barátok közt    NaN          1998         NaN
# 445890                 My Super Sweet 16    NaN          2005         NaN
# 1364951              Toddlers and Tiaras    NaN          2009         NaN
#
#          ocena                                               opis  \
# id
# 4202274    9.9  Filthy Frank and his disease ridden friends ta...
# 6111552    9.8  In an effort to bring justice to the YouTube c...
# 903747     9.5  A high school chemistry teacher diagnosed with...
# 944947     9.5  Nine noble families fight for control over the...
# 158417     9.4  The epic story of the family feud between the ...
# 5851616    9.4  Follows two guys and their adventures in Kingd...
# 2861424    9.4  An animated series that follows the exploits o...
# 306414     9.3  Baltimore drug scene, seen through the eyes of...
# 4742876    9.3  A story of trials and tribulations of four you...
# 5697728    9.3  Kuch Rang Pyar Ke Aise Bhi is a mature love st...
# ...        ...                                                ...
# 1491299    3.3  Two of the Kardashian sisters go to Miami Beac...
# 348894     3.1  A single bachelorette dates multiple men over ...
# 468999     3.1  <a href="/updates?update=tt0468999%3Aoutlines....
# 313038     3.0  A single bachelor dates multiple women over se...
# 123366     2.9  A panel of four real women discuss everyday is...
# 1086761    2.8  A peek inside the exploits and privileged priv...
# 2288050    2.6  A reality TV show featuring the life of Toddle...
# 175383     2.4  Miklos introduces viewrs in the wolrd of Money...
# 445890     1.9    Teenagers throw epic sweet 16 birthday parties.
# 1364951    1.8      A look at the world of child beauty pageants.
#
#          stevilo_glasov  dolzina
# id
# 4202274           28354     12.0
# 6111552            3722     20.0
# 903747          1023499     49.0
# 944947          1241629     57.0
# 158417             4199     45.0
# 5851616            4143     25.0
# 2861424          162789     22.0
# 306414           214262     59.0
# 4742876           37796     40.0
# 5697728            2783     22.0
# ...                 ...      ...
# 1491299            3011     60.0
# 348894             3805     60.0
# 468999             4073     30.0
# 313038             4825     60.0
# 123366             4859     60.0
# 1086761           21830     44.0
# 2288050            6937     60.0
# 175383             3263     25.0
# 445890             2765     30.0
# 1364951            3189      NaN
#
# [2000 rows x 8 columns]

# %% [markdown]
# ### Skupine

# %% [markdown]
# Z metodo `.groupby` ustvarimo razpredelnico posebne vrste, v katerem so vrstice združene glede na skupno lastnost.

# %%
serije_po_letih = serije.groupby('leto_zacetka')

# %%
# povprečna ocena vsakega leta
serije_po_letih['ocena'].mean()
# Out:
# leto_zacetka
# 1951    8.400000
# 1955    8.400000
# 1957    7.633333
# 1959    8.150000
# 1960    7.460000
# 1961    7.675000
# 1962    7.575000
# 1963    7.833333
# 1964    7.766667
# 1965    7.462500
#           ...
# 2008    7.544262
# 2009    7.365000
# 2010    7.624731
# 2011    7.485714
# 2012    7.510619
# 2013    7.591892
# 2014    7.669919
# 2015    7.645038
# 2016    7.553333
# 2017    7.524074
# Name: ocena, Length: 62, dtype: float64

# %%
# če želimo, lahko združujemo tudi po izračunanih lastnostih
serije['petletka'] = 5 * (serije.leto_zacetka // 5)
serije
# Out:
#                                    ime oznaka  leto_zacetka  leto_konca  \
# id
# 944947                  Igra prestolov    NaN          2011         NaN
# 903747                      Kriva pota    NaN          2008      2013.0
# 1520211                   Zivi mrtveci    NaN          2010         NaN
# 1475582                       Sherlock    NaN          2010         NaN
# 898266                  Veliki pokovci    NaN          2007         NaN
# 108778                      Prijatelji    NaN          1994      2004.0
# 773262                          Dexter    NaN          2006      2013.0
# 460649    Kako sem spoznal vajino mamo    NaN          2005      2014.0
# 411008                Skrivnostni otok    NaN          2004      2010.0
# 455275                   Beg iz zapora    NaN          2005         NaN
# ...                                ...    ...           ...         ...
# 83479                    Silver Spoons    NaN          1982      1987.0
# 2817246  Girlfriends' Guide to Divorce    NaN          2014         NaN
# 73955                            Alice    NaN          1976      1985.0
# 262151                 Bob the Builder    NaN          1998         NaN
# 94511              Mission: Impossible    NaN          1988      1990.0
# 264244    Il était une fois... l'homme    NaN          1978         NaN
# 202741                    The Man Show    NaN          1999      2014.0
# 377253                Rosemary & Thyme    NaN          2003      2006.0
# 112225                        Wishbone    NaN          1995      1998.0
# 5537534                           Ajin    NaN          2016         NaN
#
#          ocena                                               opis  \
# id
# 944947     9.5  Nine noble families fight for control over the...
# 903747     9.5  A high school chemistry teacher diagnosed with...
# 1520211    8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 1475582    9.2  A modern update finds the famous sleuth and hi...
# 898266     8.3  A woman who moves into an apartment across the...
# 108778     8.9  Follows the personal and professional lives of...
# 773262     8.7  By day, mild-mannered Dexter is a blood-spatte...
# 460649     8.4  A father recounts to his children, through a s...
# 411008     8.4  The survivors of a plane crash are forced to w...
# 455275     8.4  Due to a political conspiracy, an innocent man...
# ...        ...                                                ...
# 83479      6.1  Ricky Stratton is a spoiled rich kid who lives...
# 2817246    6.9  Follows a best-selling author of a self-help b...
# 73955      6.9  A greasy-spoon diner in Phoenix, Arizona is th...
# 262151     5.4  Bob the Builder is the animated adventures of ...
# 94511      7.6  An elite covert operations unit carries out hi...
# 264244     8.1  A comprehensive animated survey of the evoluti...
# 202741     6.8  A comedic talk show geared toward men, and the...
# 377253     7.7  Set amongst the stunning gardens of Europe, Ro...
# 112225     8.4  An intelligent and witty dog imagines himself ...
# 5537534    7.8  17 years ago, immortals first appeared on the ...
#
#          stevilo_glasov  dolzina  petletka
# id
# 944947          1241629     57.0      2010
# 903747          1023499     49.0      2005
# 1520211          710538     44.0      2010
# 1475582          602975     88.0      2010
# 898266           579154     22.0      2005
# 108778           552940     22.0      1990
# 773262           545745     53.0      2005
# 460649           491728     22.0      2005
# 411008           417078     44.0      2000
# 455275           393278     44.0      2005
# ...                 ...      ...       ...
# 83479              2681     30.0      1980
# 2817246            2680     60.0      2010
# 73955              2677     30.0      1975
# 262151             2673     10.0      1995
# 94511              2668     47.0      1985
# 264244             2668     25.0      1975
# 202741             2662     30.0      1995
# 377253             2656     60.0      2000
# 112225             2656     30.0      1995
# 5537534            2646     24.0      2015
#
# [2000 rows x 9 columns]

# %%
serije_po_petletkah = serije.groupby('petletka')

# %% [markdown]
# Preštejemo, koliko filmov je bilo v vsakem petletki. Pri večini stolpcev dobimo iste številke, ker imamo v vsakem stolpcu enako vnosov. Če kje kakšen podatek manjkal, je številka manjša.

# %%
serije_po_petletkah.count()
# Out:
#           ime  oznaka  leto_zacetka  leto_konca  ocena  opis  stevilo_glasov  \
# petletka
# 1950        1       0             1           1      1     1               1
# 1955        8       0             8           7      8     8               8
# 1960       22       0            22          20     22    22              22
# 1965       29       0            29          27     29    29              29
# 1970       29       0            29          26     29    29              29
# 1975       34       0            34          32     34    34              34
# 1980       49       1            49          46     49    49              49
# 1985       82       0            82          65     82    82              82
# 1990      122       0           122         111    122   122             122
# 1995      168       2           168         132    168   168             168
# 2000      235       3           235         179    235   235             235
# 2005      350       7           350         228    350   350             350
# 2010      566       7           566         257    566   566             566
# 2015      305       5           305          42    305   305             305
#
#           dolzina
# petletka
# 1950            1
# 1955            8
# 1960           22
# 1965           29
# 1970           29
# 1975           34
# 1980           49
# 1985           82
# 1990          120
# 1995          167
# 2000          226
# 2005          324
# 2010          542
# 2015          303

# %% [markdown]
# Če želimo dobiti le število članov posamezne skupine, uporabimo metodo `.size()`. V tem primeru dobimo le stolpec, ne razpredelnice.

# %%
serije_po_petletkah.size()
# Out:
# petletka
# 1950      1
# 1955      8
# 1960     22
# 1965     29
# 1970     29
# 1975     34
# 1980     49
# 1985     82
# 1990    122
# 1995    168
# 2000    235
# 2005    350
# 2010    566
# 2015    305
# dtype: int64

# %% [markdown]
# Pogledamo povprečja vsake petletke. Dobimo povprečni leti začetka in konca (torej povprečno vsake serije v dani petletki), povprečno oceno, število glasov in dolžino. Povprečnega imena ne dobimo, ker se ga ne da izračunati, zato ustreznega stolpca ni.

# %%
serije_po_petletkah.mean()
# Out:
#           leto_zacetka   leto_konca     ocena  stevilo_glasov    dolzina
# petletka
# 1950       1951.000000  1957.000000  8.400000    18807.000000  30.000000
# 1955       1956.750000  1965.571429  8.050000    10916.125000  41.875000
# 1960       1962.045455  1969.100000  7.654545     9353.818182  36.409091
# 1965       1966.965517  1974.851852  7.882759     9857.724138  40.862069
# 1970       1972.517241  1979.576923  7.782759     6933.068966  44.724138
# 1975       1976.852941  1983.062500  7.391176     9358.411765  44.970588
# 1980       1982.612245  1988.239130  7.534694    10209.367347  57.040816
# 1985       1987.012195  1993.261538  7.520732    19009.268293  45.792683
# 1990       1992.295082  1998.612613  7.557377    18470.442623  47.275000
# 1995       1997.071429  2002.174242  7.497024    22433.267857  45.862275
# 2000       2002.314894  2007.229050  7.471064    26018.646809  50.995575
# 2005       2007.068571  2010.951754  7.486286    34948.002857  41.814815
# 2010       2012.079505  2014.202335  7.574382    28562.204947  43.071956
# 2015       2015.747541  2016.642857  7.587541    18835.862295  47.900990

# %% [markdown]
# ## Risanje grafov

# %%
# vključimo risanje grafov (če stvari začnejo delati počasneje, izklopimo možnost inline)
# %matplotlib inline

# %% [markdown]
# Običajen graf dobimo z metodo `plot`. Uporabljamo ga, kadar želimo prikazati spreminjanje vrednosti v odvisnosti od zvezne spremenljivke

# %% [markdown]
# Naša hipoteza je, da je v zadnjih časih vedno več dobrih serij. Graf to potrjuje.

# %%
serije[
    (serije['ocena'] > 8.5) & (serije['leto_zacetka'] < 2015)
].groupby('petletka').size().plot()

# %% [markdown]
# Ali je v zadnjih časih tudi vedno več slabih serij? Včasih je bilo to res, zdaj pa ni več videti.

# %%
serije[
    (serije['ocena'] < 6.0) & (serije['leto_zacetka'] < 2015)
].groupby('petletka').size().plot()

# %% [markdown]
# Razsevni diagram dobimo z metodo `plot.scatter`. Uporabljamo ga, če želimo ugotoviti povezavo med dvema spremenljivkama.

# %%
serije.plot.scatter('leto_zacetka', 'leto_konca')

# %% [markdown]
# Stolpčni diagram dobimo z metodo `plot.bar`. Uporabljamo ga, če želimo primerjati vrednosti pri diskretnih (običajno kategoričnih) spremenljivkah. Pogosto je koristno, da graf uredimo po vrednostih.

# %%
serije.sort_values('stevilo_glasov', ascending=False).head(20).plot.bar(x='ime', y='stevilo_glasov')

# %% [markdown]
# ## Stikanje podatkov

# %%
igralci = pd.read_csv('igralci.csv', index_col='id')
vloge = pd.read_csv('vloge.csv')
zanri = pd.read_csv('zanri.csv')

# %% [markdown]
# Razpredelnice združujemo s funkcijo `merge`, ki vrne razpredelnico vnosov iz obeh tabel, pri katerih se vsi istoimenski podatki ujemajo.

# %%
vloge[vloge['serija'] == 944947]
# Out:
#    serija  igralec
# 0  944947  3592338
# 1  944947   227759
# 2  944947  3229685
# 3  944947   372176

# %%
zanri[zanri['serija'] == 944947]
# Out:
#    serija       zanr
# 0  944947  Adventure
# 1  944947      Drama
# 2  944947    Fantasy

# %%
pd.merge(vloge, zanri)
# Out:
#         serija  igralec       zanr
# 0       944947  3592338  Adventure
# 1       944947  3592338      Drama
# 2       944947  3592338    Fantasy
# 3       944947   227759  Adventure
# 4       944947   227759      Drama
# 5       944947   227759    Fantasy
# 6       944947  3229685  Adventure
# 7       944947  3229685      Drama
# 8       944947  3229685    Fantasy
# 9       944947   372176  Adventure
# ...        ...      ...        ...
# 18971  5537534  1465001      Drama
# 18972  5537534   784614  Animation
# 18973  5537534   784614  Adventure
# 18974  5537534   784614      Drama
# 18975  5537534   757327  Animation
# 18976  5537534   757327  Adventure
# 18977  5537534   757327      Drama
# 18978  5537534  4262853  Animation
# 18979  5537534  4262853  Adventure
# 18980  5537534  4262853      Drama
#
# [18981 rows x 3 columns]

# %% [markdown]
# Poglejmo, kateri igralec je igral v največ komedijah.

# %%
zanri_vlog = pd.merge(vloge, zanri)
zanri_vlog[
    zanri_vlog['zanr'] == 'Comedy'
].groupby(
    'igralec'
).size().sort_values(ascending=False)
# Out:
# igralec
# 674775      1
# 1001030     1
# 1002289     1
# 1002609     1
# 1004294     1
# 1004774     1
# 1004811     1
# 1006297     1
# 1006741     1
# 999118      1
#            ..
# 152839      6
# 667326      6
# 305         7
# 781899      7
# 100         7
# 315041      7
# 4715        7
# 191906      8
# 919798      9
# 444786     11
# Length: 3021, dtype: int64

# %% [markdown]
# ### Povprečne ocene žanrov

# %% [markdown]
# V osnovi vsebuje združena razpredelnica le tiste vnose, ki se pojavijo v obeh tabelah. Temu principu pravimo notranji stik (_inner join_). Lahko pa se odločimo, da izberemo tudi tiste vnose, ki imajo podatke le v levi tabeli (_left join_), le v desni tabeli (_right join_) ali v vsaj eni tabeli (_outer join_). Če v eni tabeli ni vnosov, bodo v združeni tabeli označene manjkajoče vrednosti. Ker smo v našem primeru podatke jemali iz IMDBja, kjer so za vsak film določeni tako žanri kot vloge, do razlik ne pride.

# %% [markdown]
# Če želimo razpredelnice združevati po ključih, namesto `merge` uporabimo `join` (ki v ozadju uporablja `merge`).

# %%
zanri.join(serije, on='serija')
# Out:
#        serija       zanr               ime oznaka  leto_zacetka  leto_konca  \
# 0      944947  Adventure    Igra prestolov    NaN          2011         NaN
# 1      944947      Drama    Igra prestolov    NaN          2011         NaN
# 2      944947    Fantasy    Igra prestolov    NaN          2011         NaN
# 3      903747      Crime        Kriva pota    NaN          2008      2013.0
# 4      903747      Drama        Kriva pota    NaN          2008      2013.0
# 5      903747   Thriller        Kriva pota    NaN          2008      2013.0
# 6     1520211      Drama      Zivi mrtveci    NaN          2010         NaN
# 7     1520211     Horror      Zivi mrtveci    NaN          2010         NaN
# 8     1520211   Thriller      Zivi mrtveci    NaN          2010         NaN
# 9     1475582      Crime          Sherlock    NaN          2010         NaN
# ...       ...        ...               ...    ...           ...         ...
# 4741   202741  Talk-Show      The Man Show    NaN          1999      2014.0
# 4742   377253      Crime  Rosemary & Thyme    NaN          2003      2006.0
# 4743   377253      Drama  Rosemary & Thyme    NaN          2003      2006.0
# 4744   377253    Mystery  Rosemary & Thyme    NaN          2003      2006.0
# 4745   112225  Adventure          Wishbone    NaN          1995      1998.0
# 4746   112225     Comedy          Wishbone    NaN          1995      1998.0
# 4747   112225     Family          Wishbone    NaN          1995      1998.0
# 4748  5537534  Animation              Ajin    NaN          2016         NaN
# 4749  5537534  Adventure              Ajin    NaN          2016         NaN
# 4750  5537534      Drama              Ajin    NaN          2016         NaN
#
#       ocena                                               opis  \
# 0       9.5  Nine noble families fight for control over the...
# 1       9.5  Nine noble families fight for control over the...
# 2       9.5  Nine noble families fight for control over the...
# 3       9.5  A high school chemistry teacher diagnosed with...
# 4       9.5  A high school chemistry teacher diagnosed with...
# 5       9.5  A high school chemistry teacher diagnosed with...
# 6       8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 7       8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 8       8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 9       9.2  A modern update finds the famous sleuth and hi...
# ...     ...                                                ...
# 4741    6.8  A comedic talk show geared toward men, and the...
# 4742    7.7  Set amongst the stunning gardens of Europe, Ro...
# 4743    7.7  Set amongst the stunning gardens of Europe, Ro...
# 4744    7.7  Set amongst the stunning gardens of Europe, Ro...
# 4745    8.4  An intelligent and witty dog imagines himself ...
# 4746    8.4  An intelligent and witty dog imagines himself ...
# 4747    8.4  An intelligent and witty dog imagines himself ...
# 4748    7.8  17 years ago, immortals first appeared on the ...
# 4749    7.8  17 years ago, immortals first appeared on the ...
# 4750    7.8  17 years ago, immortals first appeared on the ...
#
#       stevilo_glasov  dolzina
# 0            1241629     57.0
# 1            1241629     57.0
# 2            1241629     57.0
# 3            1023499     49.0
# 4            1023499     49.0
# 5            1023499     49.0
# 6             710538     44.0
# 7             710538     44.0
# 8             710538     44.0
# 9             602975     88.0
# ...              ...      ...
# 4741            2662     30.0
# 4742            2656     60.0
# 4743            2656     60.0
# 4744            2656     60.0
# 4745            2656     30.0
# 4746            2656     30.0
# 4747            2656     30.0
# 4748            2646     24.0
# 4749            2646     24.0
# 4750            2646     24.0
#
# [4751 rows x 10 columns]

# %% [markdown]
# Enako bi lahko dosegli s funkcijo `merge`, vendar bi poprej razpredelnici `filmi` morali stolpec `id` iz indeksa pretvoriti v običajni stolpec. Ker razpredelnici nimata enako poimenovanih stolpcev, moramo posebej povedati, katere leve stolpce združimo s katerimi desnimi.

# %%
pd.merge(zanri, serije.reset_index(), left_on='serija', right_on='id')
# Out:
#        serija       zanr       id               ime oznaka  leto_zacetka  \
# 0      944947  Adventure   944947    Igra prestolov    NaN          2011
# 1      944947      Drama   944947    Igra prestolov    NaN          2011
# 2      944947    Fantasy   944947    Igra prestolov    NaN          2011
# 3      903747      Crime   903747        Kriva pota    NaN          2008
# 4      903747      Drama   903747        Kriva pota    NaN          2008
# 5      903747   Thriller   903747        Kriva pota    NaN          2008
# 6     1520211      Drama  1520211      Zivi mrtveci    NaN          2010
# 7     1520211     Horror  1520211      Zivi mrtveci    NaN          2010
# 8     1520211   Thriller  1520211      Zivi mrtveci    NaN          2010
# 9     1475582      Crime  1475582          Sherlock    NaN          2010
# ...       ...        ...      ...               ...    ...           ...
# 4741   202741  Talk-Show   202741      The Man Show    NaN          1999
# 4742   377253      Crime   377253  Rosemary & Thyme    NaN          2003
# 4743   377253      Drama   377253  Rosemary & Thyme    NaN          2003
# 4744   377253    Mystery   377253  Rosemary & Thyme    NaN          2003
# 4745   112225  Adventure   112225          Wishbone    NaN          1995
# 4746   112225     Comedy   112225          Wishbone    NaN          1995
# 4747   112225     Family   112225          Wishbone    NaN          1995
# 4748  5537534  Animation  5537534              Ajin    NaN          2016
# 4749  5537534  Adventure  5537534              Ajin    NaN          2016
# 4750  5537534      Drama  5537534              Ajin    NaN          2016
#
#       leto_konca  ocena                                               opis  \
# 0            NaN    9.5  Nine noble families fight for control over the...
# 1            NaN    9.5  Nine noble families fight for control over the...
# 2            NaN    9.5  Nine noble families fight for control over the...
# 3         2013.0    9.5  A high school chemistry teacher diagnosed with...
# 4         2013.0    9.5  A high school chemistry teacher diagnosed with...
# 5         2013.0    9.5  A high school chemistry teacher diagnosed with...
# 6            NaN    8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 7            NaN    8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 8            NaN    8.5  Sheriff Deputy Rick Grimes wakes up from a com...
# 9            NaN    9.2  A modern update finds the famous sleuth and hi...
# ...          ...    ...                                                ...
# 4741      2014.0    6.8  A comedic talk show geared toward men, and the...
# 4742      2006.0    7.7  Set amongst the stunning gardens of Europe, Ro...
# 4743      2006.0    7.7  Set amongst the stunning gardens of Europe, Ro...
# 4744      2006.0    7.7  Set amongst the stunning gardens of Europe, Ro...
# 4745      1998.0    8.4  An intelligent and witty dog imagines himself ...
# 4746      1998.0    8.4  An intelligent and witty dog imagines himself ...
# 4747      1998.0    8.4  An intelligent and witty dog imagines himself ...
# 4748         NaN    7.8  17 years ago, immortals first appeared on the ...
# 4749         NaN    7.8  17 years ago, immortals first appeared on the ...
# 4750         NaN    7.8  17 years ago, immortals first appeared on the ...
#
#       stevilo_glasov  dolzina
# 0            1241629     57.0
# 1            1241629     57.0
# 2            1241629     57.0
# 3            1023499     49.0
# 4            1023499     49.0
# 5            1023499     49.0
# 6             710538     44.0
# 7             710538     44.0
# 8             710538     44.0
# 9             602975     88.0
# ...              ...      ...
# 4741            2662     30.0
# 4742            2656     60.0
# 4743            2656     60.0
# 4744            2656     60.0
# 4745            2656     30.0
# 4746            2656     30.0
# 4747            2656     30.0
# 4748            2646     24.0
# 4749            2646     24.0
# 4750            2646     24.0
#
# [4751 rows x 11 columns]

# %% [markdown]
# Z združeno tabelo lahko izračunamo tudi povprečno oceno glede na žanr.

# %%
zanri.join(
    serije.ocena, on='serija'
).groupby(
    'zanr'
).mean(
).sort_values(
    'ocena', ascending=False
)['ocena']
# Out:
# zanr
# Short          8.425000
# Biography      8.223077
# War            8.183333
# Documentary    8.044118
# History        7.975000
# Sport          7.836364
# Animation      7.773829
# Western        7.750000
# Crime          7.733048
# Mystery        7.700000
#                  ...
# Fantasy        7.554248
# Sci-Fi         7.521429
# News           7.485714
# Talk-Show      7.366667
# Romance        7.264118
# Music          7.170833
# Family         7.126027
# Musical        6.880000
# Game-Show      6.763636
# Reality-TV     5.909589
# Name: ocena, Length: 26, dtype: float64

# %% [markdown]
# Poglejmo, kako popularni so bili posamezni žanri skozi desetletja. Najprej vsakemu filmu dodajmo še stolpec z desetletjem.

# %%
serije['desetletje'] = 10 * (serije['leto_zacetka'] // 10)

# %% [markdown]
# Nato poglejmo, koliko je bilo filmov posameznega žanra v vsakem desetletju.

# %%
zastopanost_zanrov = zanri.join(
    serije, on='serija'
).groupby(
    ['desetletje', 'zanr']
).size()
zastopanost_zanrov
# Out:
# desetletje  zanr
# 1950        Animation      1
#             Comedy         4
#             Crime          2
#             Drama          2
#             Family         4
#             Fantasy        1
#             Horror         1
#             Mystery        3
#             Western        2
# 1960        Action        11
#                           ..
# 2010        News           3
#             Reality-TV    20
#             Romance       67
#             Sci-Fi        61
#             Short          2
#             Sport          8
#             Talk-Show     19
#             Thriller      66
#             War            3
#             Western        1
# Length: 135, dtype: int64

# %% [markdown]
# Ker smo združevali po več lastnostih, smo dobili stolpec s hierarhičnim indeksom. Tega lahko pretvorimo v matriko z metodo `.unstack`.

# %%
matrika_zastopanosti = zastopanost_zanrov.unstack()
matrika_zastopanosti
# Out:
# zanr        Action  Adventure  Animation  Biography  Comedy  Crime  \
# desetletje
# 1950           NaN        NaN        1.0        NaN     4.0    2.0
# 1960          11.0       10.0       15.0        NaN    31.0    7.0
# 1970          15.0       18.0        5.0        NaN    36.0   11.0
# 1980          35.0       32.0       35.0        NaN    70.0   22.0
# 1990          70.0       67.0      101.0        1.0   158.0   33.0
# 2000         119.0       92.0      128.0        1.0   281.0   93.0
# 2010         159.0       90.0       78.0       11.0   345.0  183.0
#
# zanr        Documentary  Drama  Family  Fantasy   ...     News  Reality-TV  \
# desetletje                                        ...
# 1950                NaN    2.0     4.0      1.0   ...      NaN         NaN
# 1960                NaN   10.0    25.0      7.0   ...      NaN         NaN
# 1970                1.0   26.0    10.0      NaN   ...      NaN         NaN
# 1980                1.0   43.0    32.0      7.0   ...      NaN         2.0
# 1990                3.0  101.0    62.0     22.0   ...      2.0         2.0
# 2000               17.0  262.0    59.0     41.0   ...      2.0        49.0
# 2010               12.0  534.0    27.0     75.0   ...      3.0        20.0
#
# zanr        Romance  Sci-Fi  Short  Sport  Talk-Show  Thriller  War  Western
# desetletje
# 1950            NaN     NaN    NaN    NaN        NaN       NaN  NaN      2.0
# 1960            3.0     3.0    NaN    1.0        NaN       NaN  2.0      NaN
# 1970            6.0     5.0    NaN    NaN        NaN       1.0  1.0      1.0
# 1980            9.0    10.0    1.0    1.0        2.0       NaN  4.0      NaN
# 1990           29.0    21.0    NaN    5.0       11.0       4.0  NaN      2.0
# 2000           56.0    40.0    1.0    7.0       13.0      20.0  2.0      NaN
# 2010           67.0    61.0    2.0    8.0       19.0      66.0  3.0      1.0
#
# [7 rows x 26 columns]

# %% [markdown]
# Ker nas zanima le popularnost žanra v posameznem desetletju, želimo za vsak stolpec izračunati razmerje števila filmov danega žanra glede na število vseh filmov. To storimo s pomočjo metode `.apply`, ki v dani razpredelnici dano funkcijo uporabi na vsaki vrstici ali stolpcu (če dodamo možnost `axis=1`). Če bi želeli funkcijo uporabiti na vsakem elementu stolpca, bi namesto `.apply` uporabili `.map`.

# %%
matrika_popularnosti = matrika_zastopanosti.apply(lambda st: st / st.sum(), axis=1)
matrika_popularnosti
# Out:
# zanr          Action  Adventure  Animation  Biography    Comedy     Crime  \
# desetletje
# 1950             NaN        NaN   0.050000        NaN  0.200000  0.100000
# 1960        0.081481   0.074074   0.111111        NaN  0.229630  0.051852
# 1970        0.103448   0.124138   0.034483        NaN  0.248276  0.075862
# 1980        0.109034   0.099688   0.109034        NaN  0.218069  0.068536
# 1990        0.095368   0.091281   0.137602   0.001362  0.215259  0.044959
# 2000        0.083450   0.064516   0.089762   0.000701  0.197055  0.065217
# 2010        0.080711   0.045685   0.039594   0.005584  0.175127  0.092893
#
# zanr        Documentary     Drama    Family   Fantasy    ...         News  \
# desetletje                                               ...
# 1950                NaN  0.100000  0.200000  0.050000    ...          NaN
# 1960                NaN  0.074074  0.185185  0.051852    ...          NaN
# 1970           0.006897  0.179310  0.068966       NaN    ...          NaN
# 1980           0.003115  0.133956  0.099688  0.021807    ...          NaN
# 1990           0.004087  0.137602  0.084469  0.029973    ...     0.002725
# 2000           0.011921  0.183731  0.041374  0.028752    ...     0.001403
# 2010           0.006091  0.271066  0.013706  0.038071    ...     0.001523
#
# zanr        Reality-TV   Romance    Sci-Fi     Short     Sport  Talk-Show  \
# desetletje
# 1950               NaN       NaN       NaN       NaN       NaN        NaN
# 1960               NaN  0.022222  0.022222       NaN  0.007407        NaN
# 1970               NaN  0.041379  0.034483       NaN       NaN        NaN
# 1980          0.006231  0.028037  0.031153  0.003115  0.003115   0.006231
# 1990          0.002725  0.039510  0.028610       NaN  0.006812   0.014986
# 2000          0.034362  0.039271  0.028050  0.000701  0.004909   0.009116
# 2010          0.010152  0.034010  0.030964  0.001015  0.004061   0.009645
#
# zanr        Thriller       War   Western
# desetletje
# 1950             NaN       NaN  0.100000
# 1960             NaN  0.014815       NaN
# 1970        0.006897  0.006897  0.006897
# 1980             NaN  0.012461       NaN
# 1990        0.005450       NaN  0.002725
# 2000        0.014025  0.001403       NaN
# 2010        0.033503  0.001523  0.000508
#
# [7 rows x 26 columns]

# %%
matrika_popularnosti.plot(kind='area')

# %% [markdown]
# Zgornji graf je čisto nepregleden. Omejimo se le na 10 najpopularnejših žanrov.

# %%
najpopularnejsi_zanri = zanri.groupby('zanr').size().sort_values(ascending=False)

# %%
najpopularnejsi_zanri
# Out:
# zanr
# Drama          978
# Comedy         925
# Action         409
# Animation      363
# Crime          351
# Adventure      309
# Mystery        234
# Family         219
# Romance        170
# Fantasy        153
#               ...
# Documentary     34
# Game-Show       33
# History         32
# Sport           22
# Biography       13
# War             12
# Musical         10
# News             7
# Western          6
# Short            4
# Length: 26, dtype: int64

# %% [markdown]
# Prve štiri žanre ignorirajmo, ker so precej generični.

# %%
zanimivi_zanri = najpopularnejsi_zanri[4:14]

# %%
zanri[zanri['zanr'].isin(list(zanimivi_zanri.index))]
zastopanost_zanrov = zanri[zanri['zanr'].isin(list(zanimivi_zanri.index))].join(
    serije, on='serija'
).groupby(
    ['desetletje', 'zanr']
).size()
matrika_zastopanosti = zastopanost_zanrov.unstack()
matrika_popularnosti = matrika_zastopanosti.apply(lambda st: st / st.sum(), axis=1)
matrika_popularnosti.plot(kind='area')

# %% [markdown]
# Vidimo, da je v prešnjem desetletju bilo precej resničnostnih oddaj ter da delež družinskih serij pada.

# %% [markdown]
# ## Avtomatično določanje žanrov

# %%
def koren_besede(beseda):
    beseda = ''.join(znak for znak in beseda if znak.isalpha())
    if not beseda:
        return '$'
    konec = len(beseda) - 1
    if beseda[konec] in 'ds':
        konec -= 1
    while konec >= 0 and beseda[konec] in 'aeiou':
        konec -= 1
    return beseda[:konec + 1]

def koreni_besed(niz):
    return pd.Series(list({
        koren_besede(beseda) for beseda in niz.replace('-', ' ').lower().split() if beseda
    }))

def koreni_filmov(nizi):
    return nizi[nizi.notnull()].apply(
        koreni_besed
    ).stack().reset_index(level=1, drop=True)

def verjetnosti_po_zanrih(dogodki_po_filmih):
    dogodki_po_filmih.name = 'dogodek'
    dogodki_po_zanrih = zanri.join(pd.DataFrame(dogodki_po_filmih), on='serija')
    pogostost_dogodkov = pd.crosstab(dogodki_po_zanrih.dogodek, dogodki_po_zanrih.zanr)
    pogostost_dogodkov += 1
    return pogostost_dogodkov / pogostost_dogodkov.sum()

# %%
verjetnost_zanra = zanri.groupby('zanr').size() / len(serije)
verjetnost_korena_pri_zanru = verjetnosti_po_zanrih(koreni_filmov(serije.opis))

# %%
verjetnost_zanra
# Out:
# zanr
# Action         0.2045
# Adventure      0.1545
# Animation      0.1815
# Biography      0.0065
# Comedy         0.4625
# Crime          0.1755
# Documentary    0.0170
# Drama          0.4890
# Family         0.1095
# Fantasy        0.0765
#                 ...
# News           0.0035
# Reality-TV     0.0365
# Romance        0.0850
# Sci-Fi         0.0700
# Short          0.0020
# Sport          0.0110
# Talk-Show      0.0225
# Thriller       0.0455
# War            0.0060
# Western        0.0030
# Length: 26, dtype: float64

# %%
verjetnost_korena_pri_zanru.Horror.sort_values(ascending=False).head(30)
# Out:
# dogodek
#             0.007691
# th          0.005128
# of          0.004895
# an          0.004545
# t           0.003613
# in          0.003146
# h           0.002331
# with        0.002214
# for         0.001748
# by          0.001748
#               ...
# when        0.001049
# family      0.001049
# liv         0.000932
# myster      0.000932
# young       0.000932
# vampir      0.000932
# from        0.000932
# discover    0.000932
# ar          0.000932
# turn        0.000932
# Name: Horror, Length: 30, dtype: float64

# %%
verjetnost_korena_pri_zanru['Reality-TV'].sort_values(ascending=False).head(30)
# Out:
# dogodek
#                    0.006799
# th                 0.006453
# of                 0.005646
# an                 0.005531
# in                 0.004840
# t                  0.003342
# on                 0.002535
# $                  0.002420
# s                  0.002189
# summaryanbspraq    0.001959
#                      ...
# reality            0.001383
# they               0.001268
# each               0.001268
# which              0.001152
# americ             0.001152
# lif                0.001152
# worl               0.001152
# liv                0.001152
# follow             0.001152
# women              0.000922
# Name: Reality-TV, Length: 30, dtype: float64

# %%
def doloci_zanre(opis):
    faktorji_zanrov = verjetnost_zanra * verjetnost_korena_pri_zanru[
        verjetnost_korena_pri_zanru.index.isin(
            koreni_besed(opis)
        )
    ].prod()
    faktorji_zanrov /= max(faktorji_zanrov)
    return faktorji_zanrov.sort_values(ascending=False).head(5)

# %%
doloci_zanre('A couple of detectives fall in love')
# Out:
# zanr
# Drama      1.000000
# Comedy     0.468212
# Romance    0.015216
# Crime      0.006567
# Action     0.004616
# dtype: float64
