# %% [markdown]
# # Memoizacija v Pythonu

# %% [markdown]
# ## Dinamično programiranje

# %% [markdown]
# 1. rešitve podnalog **sestavljajo** rešitev celote in
# 2. podnaloge se **prekrivajo**
#
# ![](../../zapiski/slike/dinamicno-programiranje.png)

# %% [markdown]
# ![](../../zapiski/slike/izracun-vnaprej1.png)

# %% [markdown]
# ## Memoizacija

# %%
def kvadrat(x):
    print(f'Računam {x}^2')
    y = x ** 2
    return y

# %%
k = kvadrat(10)
# Out:
# Računam 10^2

# %%
k
# Out:
# 100

# %%
ze_izracunani_kvadrati = {}

def memo_kvadrat(x):
    if x in ze_izracunani_kvadrati:
        return ze_izracunani_kvadrati[x]
    else:
        ze_izracunani_kvadrati[x] = kvadrat(x)
        return ze_izracunani_kvadrati[x]

# %%
memo_kvadrat(5)
# Out:
# 25

# %%
def fib(n):
    print(f'Računam fib({n})')
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(5)
# Out:
# Računam fib(5)
# Računam fib(4)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(1)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(1)
# 5

# %%
ze_izracunani_fibi = {}

def memo_fib(n):
    if n in ze_izracunani_fibi:
        return ze_izracunani_fibi[n]
    else:
        ze_izracunani_fibi[n] = fib(n)
        return ze_izracunani_fibi[n]

# %%
ze_izracunani_kvadrati[7] = 42

# %%
memo_fib(6)
# Out:
# Računam fib(6)
# Računam fib(5)
# Računam fib(4)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(1)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(1)
# Računam fib(4)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# Računam fib(1)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# 8

# %%
memo_kvadrat(7)
# Out:
# 42

# %%
def memo_kvadrat_s_skritim_slovarjem(n):
    ze_izracunani_kvadrati = {}
    if n in ze_izracunani_kvadrati:
        return ze_izracunani_kvadrati[n]
    else:
        ze_izracunani_kvadrati[n] = kvadrat(n)
        return ze_izracunani_kvadrati[n]

# %%
memo_kvadrat_s_skritim_slovarjem(5)
# Out:
# Računam 5^2
# 25

# %% [markdown]
# ## Memoizacija kot funkcija višjega reda

# %%
def memo(f):
    rezultati = {}
    def memo_f(x):
        if x in rezultati:
            return rezultati[x]
        else:
            rezultati[x] = f(x)
            return rezultati[x]
    return memo_f

# %%
memo_kvadrat = memo(kvadrat)

# %%
memo_kvadrat(10)
# Out:
# 100

# %%
fib = memo(fib)

# %%
fib(10)
# Out:
# Računam fib(10)
# Računam fib(9)
# Računam fib(8)
# Računam fib(7)
# 55

# %% [markdown]
# ## Dekoratorji

# %%
def povej_kaj_racunas(f):
    def glasni_f(x):
        print(f"Računam f({x}) = ", end="")
        y = f(x)
        print(y)
        return y
    return glasni_f

# %%
@memo
@povej_kaj_racunas
def kub(n):
    return n ** 3

# %%
kub(5)
# Out:
# 125

# %%
@memo
def fib(n):
    print(f'Računam fib({n})')
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(10)
# Out:
# Računam fib(10)
# Računam fib(9)
# Računam fib(8)
# Računam fib(7)
# Računam fib(6)
# Računam fib(5)
# Računam fib(4)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# 55

# %%
def izracunaj_na_nic(f):
    return f(0)

# %%
@izracunaj_na_nic
def moja_funkcija(x):
    return x ** 2 + 1

# %%
moja_funkcija
# Out:
# 1

# %%
from functools import cache, lru_cache

# %%
@cache
def fib(n):
    print(f'Računam fib({n})')
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(1007)
# Out:
# Računam fib(1007)
# Računam fib(1006)
# Računam fib(1005)
# Računam fib(1004)
# Računam fib(1003)
# Računam fib(1002)
# Računam fib(1001)
# Računam fib(1000)
# Računam fib(999)
# Računam fib(998)
# Računam fib(997)
# Računam fib(996)
# Računam fib(995)
# Računam fib(994)
# Računam fib(993)
# Računam fib(992)
# Računam fib(991)
# Računam fib(990)
# Računam fib(989)
# Računam fib(988)
# Računam fib(987)
# Računam fib(986)
# Računam fib(985)
# Računam fib(984)
# Računam fib(983)
# Računam fib(982)
# Računam fib(981)
# Računam fib(980)
# Računam fib(979)
# Računam fib(978)
# Računam fib(977)
# Računam fib(976)
# Računam fib(975)
# Računam fib(974)
# Računam fib(973)
# Računam fib(972)
# Računam fib(971)
# Računam fib(970)
# Računam fib(969)
# Računam fib(968)
# Računam fib(967)
# Računam fib(966)
# Računam fib(965)
# Računam fib(964)
# Računam fib(963)
# Računam fib(962)
# Računam fib(961)
# Računam fib(960)
# Računam fib(959)
# Računam fib(958)
# Računam fib(957)
# Računam fib(956)
# Računam fib(955)
# Računam fib(954)
# Računam fib(953)
# Računam fib(952)
# Računam fib(951)
# Računam fib(950)
# Računam fib(949)
# Računam fib(948)
# Računam fib(947)
# Računam fib(946)
# Računam fib(945)
# Računam fib(944)
# Računam fib(943)
# Računam fib(942)
# Računam fib(941)
# Računam fib(940)
# Računam fib(939)
# Računam fib(938)
# Računam fib(937)
# Računam fib(936)
# Računam fib(935)
# Računam fib(934)
# Računam fib(933)
# Računam fib(932)
# Računam fib(931)
# Računam fib(930)
# Računam fib(929)
# Računam fib(928)
# Računam fib(927)
# Računam fib(926)
# Računam fib(925)
# Računam fib(924)
# Računam fib(923)
# Računam fib(922)
# Računam fib(921)
# Računam fib(920)
# Računam fib(919)
# Računam fib(918)
# Računam fib(917)
# Računam fib(916)
# Računam fib(915)
# Računam fib(914)
# Računam fib(913)
# Računam fib(912)
# Računam fib(911)
# Računam fib(910)
# Računam fib(909)
# Računam fib(908)
# Računam fib(907)
# Računam fib(906)
# Računam fib(905)
# Računam fib(904)
# Računam fib(903)
# Računam fib(902)
# Računam fib(901)
# Računam fib(900)
# Računam fib(899)
# Računam fib(898)
# Računam fib(897)
# Računam fib(896)
# Računam fib(895)
# Računam fib(894)
# Računam fib(893)
# Računam fib(892)
# Računam fib(891)
# Računam fib(890)
# Računam fib(889)
# Računam fib(888)
# Računam fib(887)
# Računam fib(886)
# Računam fib(885)
# Računam fib(884)
# Računam fib(883)
# Računam fib(882)
# Računam fib(881)
# Računam fib(880)
# Računam fib(879)
# Računam fib(878)
# Računam fib(877)
# Računam fib(876)
# Računam fib(875)
# Računam fib(874)
# Računam fib(873)
# Računam fib(872)
# Računam fib(871)
# Računam fib(870)
# Računam fib(869)
# Računam fib(868)
# Računam fib(867)
# Računam fib(866)
# Računam fib(865)
# Računam fib(864)
# Računam fib(863)
# Računam fib(862)
# Računam fib(861)
# Računam fib(860)
# Računam fib(859)
# Računam fib(858)
# Računam fib(857)
# Računam fib(856)
# Računam fib(855)
# Računam fib(854)
# Računam fib(853)
# Računam fib(852)
# Računam fib(851)
# Računam fib(850)
# Računam fib(849)
# Računam fib(848)
# Računam fib(847)
# Računam fib(846)
# Računam fib(845)
# Računam fib(844)
# Računam fib(843)
# Računam fib(842)
# Računam fib(841)
# Računam fib(840)
# Računam fib(839)
# Računam fib(838)
# Računam fib(837)
# Računam fib(836)
# Računam fib(835)
# Računam fib(834)
# Računam fib(833)
# Računam fib(832)
# Računam fib(831)
# Računam fib(830)
# Računam fib(829)
# Računam fib(828)
# Računam fib(827)
# Računam fib(826)
# Računam fib(825)
# Računam fib(824)
# Računam fib(823)
# Računam fib(822)
# Računam fib(821)
# Računam fib(820)
# Računam fib(819)
# Računam fib(818)
# Računam fib(817)
# Računam fib(816)
# Računam fib(815)
# Računam fib(814)
# Računam fib(813)
# Računam fib(812)
# Računam fib(811)
# Računam fib(810)
# Računam fib(809)
# Računam fib(808)
# Računam fib(807)
# Računam fib(806)
# Računam fib(805)
# Računam fib(804)
# Računam fib(803)
# Računam fib(802)
# Računam fib(801)
# Računam fib(800)
# Računam fib(799)
# Računam fib(798)
# Računam fib(797)
# Računam fib(796)
# Računam fib(795)
# Računam fib(794)
# Računam fib(793)
# Računam fib(792)
# Računam fib(791)
# Računam fib(790)
# Računam fib(789)
# Računam fib(788)
# Računam fib(787)
# Računam fib(786)
# Računam fib(785)
# Računam fib(784)
# Računam fib(783)
# Računam fib(782)
# Računam fib(781)
# Računam fib(780)
# Računam fib(779)
# Računam fib(778)
# Računam fib(777)
# Računam fib(776)
# Računam fib(775)
# Računam fib(774)
# Računam fib(773)
# Računam fib(772)
# Računam fib(771)
# Računam fib(770)
# Računam fib(769)
# Računam fib(768)
# Računam fib(767)
# Računam fib(766)
# Računam fib(765)
# Računam fib(764)
# Računam fib(763)
# Računam fib(762)
# Računam fib(761)
# Računam fib(760)
# Računam fib(759)
# Računam fib(758)
# Računam fib(757)
# Računam fib(756)
# Računam fib(755)
# Računam fib(754)
# Računam fib(753)
# Računam fib(752)
# Računam fib(751)
# Računam fib(750)
# Računam fib(749)
# Računam fib(748)
# Računam fib(747)
# Računam fib(746)
# Računam fib(745)
# Računam fib(744)
# Računam fib(743)
# Računam fib(742)
# Računam fib(741)
# Računam fib(740)
# Računam fib(739)
# Računam fib(738)
# Računam fib(737)
# Računam fib(736)
# Računam fib(735)
# Računam fib(734)
# Računam fib(733)
# Računam fib(732)
# Računam fib(731)
# Računam fib(730)
# Računam fib(729)
# Računam fib(728)
# Računam fib(727)
# Računam fib(726)
# Računam fib(725)
# Računam fib(724)
# Računam fib(723)
# Računam fib(722)
# Računam fib(721)
# Računam fib(720)
# Računam fib(719)
# Računam fib(718)
# Računam fib(717)
# Računam fib(716)
# Računam fib(715)
# Računam fib(714)
# Računam fib(713)
# Računam fib(712)
# Računam fib(711)
# Računam fib(710)
# Računam fib(709)
# Računam fib(708)
# Računam fib(707)
# Računam fib(706)
# Računam fib(705)
# Računam fib(704)
# Računam fib(703)
# Računam fib(702)
# Računam fib(701)
# Računam fib(700)
# Računam fib(699)
# Računam fib(698)
# Računam fib(697)
# Računam fib(696)
# Računam fib(695)
# Računam fib(694)
# Računam fib(693)
# Računam fib(692)
# Računam fib(691)
# Računam fib(690)
# Računam fib(689)
# Računam fib(688)
# Računam fib(687)
# Računam fib(686)
# Računam fib(685)
# Računam fib(684)
# Računam fib(683)
# Računam fib(682)
# Računam fib(681)
# Računam fib(680)
# Računam fib(679)
# Računam fib(678)
# Računam fib(677)
# Računam fib(676)
# Računam fib(675)
# Računam fib(674)
# Računam fib(673)
# Računam fib(672)
# Računam fib(671)
# Računam fib(670)
# Računam fib(669)
# Računam fib(668)
# Računam fib(667)
# Računam fib(666)
# Računam fib(665)
# Računam fib(664)
# Računam fib(663)
# Računam fib(662)
# Računam fib(661)
# Računam fib(660)
# Računam fib(659)
# Računam fib(658)
# Računam fib(657)
# Računam fib(656)
# Računam fib(655)
# Računam fib(654)
# Računam fib(653)
# Računam fib(652)
# Računam fib(651)
# Računam fib(650)
# Računam fib(649)
# Računam fib(648)
# Računam fib(647)
# Računam fib(646)
# Računam fib(645)
# Računam fib(644)
# Računam fib(643)
# Računam fib(642)
# Računam fib(641)
# Računam fib(640)
# Računam fib(639)
# Računam fib(638)
# Računam fib(637)
# Računam fib(636)
# Računam fib(635)
# Računam fib(634)
# Računam fib(633)
# Računam fib(632)
# Računam fib(631)
# Računam fib(630)
# Računam fib(629)
# Računam fib(628)
# Računam fib(627)
# Računam fib(626)
# Računam fib(625)
# Računam fib(624)
# Računam fib(623)
# Računam fib(622)
# Računam fib(621)
# Računam fib(620)
# Računam fib(619)
# Računam fib(618)
# Računam fib(617)
# Računam fib(616)
# Računam fib(615)
# Računam fib(614)
# Računam fib(613)
# Računam fib(612)
# Računam fib(611)
# Računam fib(610)
# Računam fib(609)
# Računam fib(608)
# Računam fib(607)
# Računam fib(606)
# Računam fib(605)
# Računam fib(604)
# Računam fib(603)
# Računam fib(602)
# Računam fib(601)
# Računam fib(600)
# Računam fib(599)
# Računam fib(598)
# Računam fib(597)
# Računam fib(596)
# Računam fib(595)
# Računam fib(594)
# Računam fib(593)
# Računam fib(592)
# Računam fib(591)
# Računam fib(590)
# Računam fib(589)
# Računam fib(588)
# Računam fib(587)
# Računam fib(586)
# Računam fib(585)
# Računam fib(584)
# Računam fib(583)
# Računam fib(582)
# Računam fib(581)
# Računam fib(580)
# Računam fib(579)
# Računam fib(578)
# Računam fib(577)
# Računam fib(576)
# Računam fib(575)
# Računam fib(574)
# Računam fib(573)
# Računam fib(572)
# Računam fib(571)
# Računam fib(570)
# Računam fib(569)
# Računam fib(568)
# Računam fib(567)
# Računam fib(566)
# Računam fib(565)
# Računam fib(564)
# Računam fib(563)
# Računam fib(562)
# Računam fib(561)
# Računam fib(560)
# Računam fib(559)
# Računam fib(558)
# Računam fib(557)
# Računam fib(556)
# Računam fib(555)
# Računam fib(554)
# Računam fib(553)
# Računam fib(552)
# Računam fib(551)
# Računam fib(550)
# Računam fib(549)
# Računam fib(548)
# Računam fib(547)
# Računam fib(546)
# Računam fib(545)
# Računam fib(544)
# Računam fib(543)
# Računam fib(542)
# Računam fib(541)
# Računam fib(540)
# Računam fib(539)
# Računam fib(538)
# Računam fib(537)
# Računam fib(536)
# Računam fib(535)
# Računam fib(534)
# Računam fib(533)
# Računam fib(532)
# Računam fib(531)
# Računam fib(530)
# Računam fib(529)
# Računam fib(528)
# Računam fib(527)
# Računam fib(526)
# Računam fib(525)
# Računam fib(524)
# Računam fib(523)
# Računam fib(522)
# Računam fib(521)
# Računam fib(520)
# Računam fib(519)
# Računam fib(518)
# Računam fib(517)
# Računam fib(516)
# Računam fib(515)
# Računam fib(514)
# Računam fib(513)
# Računam fib(512)
# Računam fib(511)
# Računam fib(510)
# Računam fib(509)
# Računam fib(508)
# Računam fib(507)
# Računam fib(506)
# Računam fib(505)
# Računam fib(504)
# Računam fib(503)
# Računam fib(502)
# Računam fib(501)
# Računam fib(500)
# Računam fib(499)
# Računam fib(498)
# Računam fib(497)
# Računam fib(496)
# Računam fib(495)
# Računam fib(494)
# Računam fib(493)
# Računam fib(492)
# Računam fib(491)
# Računam fib(490)
# Računam fib(489)
# Računam fib(488)
# Računam fib(487)
# Računam fib(486)
# Računam fib(485)
# Računam fib(484)
# Računam fib(483)
# Računam fib(482)
# Računam fib(481)
# Računam fib(480)
# Računam fib(479)
# Računam fib(478)
# Računam fib(477)
# Računam fib(476)
# Računam fib(475)
# Računam fib(474)
# Računam fib(473)
# Računam fib(472)
# Računam fib(471)
# Računam fib(470)
# Računam fib(469)
# Računam fib(468)
# Računam fib(467)
# Računam fib(466)
# Računam fib(465)
# Računam fib(464)
# Računam fib(463)
# Računam fib(462)
# Računam fib(461)
# Računam fib(460)
# Računam fib(459)
# Računam fib(458)
# Računam fib(457)
# Računam fib(456)
# Računam fib(455)
# Računam fib(454)
# Računam fib(453)
# Računam fib(452)
# Računam fib(451)
# Računam fib(450)
# Računam fib(449)
# Računam fib(448)
# Računam fib(447)
# Računam fib(446)
# Računam fib(445)
# Računam fib(444)
# Računam fib(443)
# Računam fib(442)
# Računam fib(441)
# Računam fib(440)
# Računam fib(439)
# Računam fib(438)
# Računam fib(437)
# Računam fib(436)
# Računam fib(435)
# Računam fib(434)
# Računam fib(433)
# Računam fib(432)
# Računam fib(431)
# Računam fib(430)
# Računam fib(429)
# Računam fib(428)
# Računam fib(427)
# Računam fib(426)
# Računam fib(425)
# Računam fib(424)
# Računam fib(423)
# Računam fib(422)
# Računam fib(421)
# Računam fib(420)
# Računam fib(419)
# Računam fib(418)
# Računam fib(417)
# Računam fib(416)
# Računam fib(415)
# Računam fib(414)
# Računam fib(413)
# Računam fib(412)
# Računam fib(411)
# Računam fib(410)
# Računam fib(409)
# Računam fib(408)
# Računam fib(407)
# Računam fib(406)
# Računam fib(405)
# Računam fib(404)
# Računam fib(403)
# Računam fib(402)
# Računam fib(401)
# Računam fib(400)
# Računam fib(399)
# Računam fib(398)
# Računam fib(397)
# Računam fib(396)
# Računam fib(395)
# Računam fib(394)
# Računam fib(393)
# Računam fib(392)
# Računam fib(391)
# Računam fib(390)
# Računam fib(389)
# Računam fib(388)
# Računam fib(387)
# Računam fib(386)
# Računam fib(385)
# Računam fib(384)
# Računam fib(383)
# Računam fib(382)
# Računam fib(381)
# Računam fib(380)
# Računam fib(379)
# Računam fib(378)
# Računam fib(377)
# Računam fib(376)
# Računam fib(375)
# Računam fib(374)
# Računam fib(373)
# Računam fib(372)
# Računam fib(371)
# Računam fib(370)
# Računam fib(369)
# Računam fib(368)
# Računam fib(367)
# Računam fib(366)
# Računam fib(365)
# Računam fib(364)
# Računam fib(363)
# Računam fib(362)
# Računam fib(361)
# Računam fib(360)
# Računam fib(359)
# Računam fib(358)
# Računam fib(357)
# Računam fib(356)
# Računam fib(355)
# Računam fib(354)
# Računam fib(353)
# Računam fib(352)
# Računam fib(351)
# Računam fib(350)
# Računam fib(349)
# Računam fib(348)
# Računam fib(347)
# Računam fib(346)
# Računam fib(345)
# Računam fib(344)
# Računam fib(343)
# Računam fib(342)
# Računam fib(341)
# Računam fib(340)
# Računam fib(339)
# Računam fib(338)
# Računam fib(337)
# Računam fib(336)
# Računam fib(335)
# Računam fib(334)
# Računam fib(333)
# Računam fib(332)
# Računam fib(331)
# Računam fib(330)
# Računam fib(329)
# Računam fib(328)
# Računam fib(327)
# Računam fib(326)
# Računam fib(325)
# Računam fib(324)
# Računam fib(323)
# Računam fib(322)
# Računam fib(321)
# Računam fib(320)
# Računam fib(319)
# Računam fib(318)
# Računam fib(317)
# Računam fib(316)
# Računam fib(315)
# Računam fib(314)
# Računam fib(313)
# Računam fib(312)
# Računam fib(311)
# Računam fib(310)
# Računam fib(309)
# Računam fib(308)
# Računam fib(307)
# Računam fib(306)
# Računam fib(305)
# Računam fib(304)
# Računam fib(303)
# Računam fib(302)
# Računam fib(301)
# Računam fib(300)
# Računam fib(299)
# Računam fib(298)
# Računam fib(297)
# Računam fib(296)
# Računam fib(295)
# Računam fib(294)
# Računam fib(293)
# Računam fib(292)
# Računam fib(291)
# Računam fib(290)
# Računam fib(289)
# Računam fib(288)
# Računam fib(287)
# Računam fib(286)
# Računam fib(285)
# Računam fib(284)
# Računam fib(283)
# Računam fib(282)
# Računam fib(281)
# Računam fib(280)
# Računam fib(279)
# Računam fib(278)
# Računam fib(277)
# Računam fib(276)
# Računam fib(275)
# Računam fib(274)
# Računam fib(273)
# Računam fib(272)
# Računam fib(271)
# Računam fib(270)
# Računam fib(269)
# Računam fib(268)
# Računam fib(267)
# Računam fib(266)
# Računam fib(265)
# Računam fib(264)
# Računam fib(263)
# Računam fib(262)
# Računam fib(261)
# Računam fib(260)
# Računam fib(259)
# Računam fib(258)
# Računam fib(257)
# Računam fib(256)
# Računam fib(255)
# Računam fib(254)
# Računam fib(253)
# Računam fib(252)
# Računam fib(251)
# Računam fib(250)
# Računam fib(249)
# Računam fib(248)
# Računam fib(247)
# Računam fib(246)
# Računam fib(245)
# Računam fib(244)
# Računam fib(243)
# Računam fib(242)
# Računam fib(241)
# Računam fib(240)
# Računam fib(239)
# Računam fib(238)
# Računam fib(237)
# Računam fib(236)
# Računam fib(235)
# Računam fib(234)
# Računam fib(233)
# Računam fib(232)
# Računam fib(231)
# Računam fib(230)
# Računam fib(229)
# Računam fib(228)
# Računam fib(227)
# Računam fib(226)
# Računam fib(225)
# Računam fib(224)
# Računam fib(223)
# Računam fib(222)
# Računam fib(221)
# Računam fib(220)
# Računam fib(219)
# Računam fib(218)
# Računam fib(217)
# Računam fib(216)
# Računam fib(215)
# Računam fib(214)
# Računam fib(213)
# Računam fib(212)
# Računam fib(211)
# Računam fib(210)
# Računam fib(209)
# Računam fib(208)
# Računam fib(207)
# Računam fib(206)
# Računam fib(205)
# Računam fib(204)
# Računam fib(203)
# Računam fib(202)
# Računam fib(201)
# Računam fib(200)
# Računam fib(199)
# Računam fib(198)
# Računam fib(197)
# Računam fib(196)
# Računam fib(195)
# Računam fib(194)
# Računam fib(193)
# Računam fib(192)
# Računam fib(191)
# Računam fib(190)
# Računam fib(189)
# Računam fib(188)
# Računam fib(187)
# Računam fib(186)
# Računam fib(185)
# Računam fib(184)
# Računam fib(183)
# Računam fib(182)
# Računam fib(181)
# Računam fib(180)
# Računam fib(179)
# Računam fib(178)
# Računam fib(177)
# Računam fib(176)
# Računam fib(175)
# Računam fib(174)
# Računam fib(173)
# Računam fib(172)
# Računam fib(171)
# Računam fib(170)
# Računam fib(169)
# Računam fib(168)
# Računam fib(167)
# Računam fib(166)
# Računam fib(165)
# Računam fib(164)
# Računam fib(163)
# Računam fib(162)
# Računam fib(161)
# Računam fib(160)
# Računam fib(159)
# Računam fib(158)
# Računam fib(157)
# Računam fib(156)
# Računam fib(155)
# Računam fib(154)
# Računam fib(153)
# Računam fib(152)
# Računam fib(151)
# Računam fib(150)
# Računam fib(149)
# Računam fib(148)
# Računam fib(147)
# Računam fib(146)
# Računam fib(145)
# Računam fib(144)
# Računam fib(143)
# Računam fib(142)
# Računam fib(141)
# Računam fib(140)
# Računam fib(139)
# Računam fib(138)
# Računam fib(137)
# Računam fib(136)
# Računam fib(135)
# Računam fib(134)
# Računam fib(133)
# Računam fib(132)
# Računam fib(131)
# Računam fib(130)
# Računam fib(129)
# Računam fib(128)
# Računam fib(127)
# Računam fib(126)
# Računam fib(125)
# Računam fib(124)
# Računam fib(123)
# Računam fib(122)
# Računam fib(121)
# Računam fib(120)
# Računam fib(119)
# Računam fib(118)
# Računam fib(117)
# Računam fib(116)
# Računam fib(115)
# Računam fib(114)
# Računam fib(113)
# Računam fib(112)
# Računam fib(111)
# Računam fib(110)
# Računam fib(109)
# Računam fib(108)
# Računam fib(107)
# Računam fib(106)
# Računam fib(105)
# Računam fib(104)
# Računam fib(103)
# Računam fib(102)
# Računam fib(101)
# Računam fib(100)
# Računam fib(99)
# Računam fib(98)
# Računam fib(97)
# Računam fib(96)
# Računam fib(95)
# Računam fib(94)
# Računam fib(93)
# Računam fib(92)
# Računam fib(91)
# Računam fib(90)
# Računam fib(89)
# Računam fib(88)
# Računam fib(87)
# Računam fib(86)
# Računam fib(85)
# Računam fib(84)
# Računam fib(83)
# Računam fib(82)
# Računam fib(81)
# Računam fib(80)
# Računam fib(79)
# Računam fib(78)
# Računam fib(77)
# Računam fib(76)
# Računam fib(75)
# Računam fib(74)
# Računam fib(73)
# Računam fib(72)
# Računam fib(71)
# Računam fib(70)
# Računam fib(69)
# Računam fib(68)
# Računam fib(67)
# Računam fib(66)
# Računam fib(65)
# Računam fib(64)
# Računam fib(63)
# Računam fib(62)
# Računam fib(61)
# Računam fib(60)
# Računam fib(59)
# Računam fib(58)
# Računam fib(57)
# Računam fib(56)
# Računam fib(55)
# Računam fib(54)
# Računam fib(53)
# Računam fib(52)
# Računam fib(51)
# Računam fib(50)
# Računam fib(49)
# Računam fib(48)
# Računam fib(47)
# Računam fib(46)
# Računam fib(45)
# Računam fib(44)
# Računam fib(43)
# Računam fib(42)
# Računam fib(41)
# Računam fib(40)
# Računam fib(39)
# Računam fib(38)
# Računam fib(37)
# Računam fib(36)
# Računam fib(35)
# Računam fib(34)
# Računam fib(33)
# Računam fib(32)
# Računam fib(31)
# Računam fib(30)
# Računam fib(29)
# Računam fib(28)
# Računam fib(27)
# Računam fib(26)
# Računam fib(25)
# Računam fib(24)
# Računam fib(23)
# Računam fib(22)
# Računam fib(21)
# Računam fib(20)
# Računam fib(19)
# Računam fib(18)
# Računam fib(17)
# Računam fib(16)
# Računam fib(15)
# Računam fib(14)
# Računam fib(13)
# Računam fib(12)
# Računam fib(11)
# Računam fib(10)
# Računam fib(9)
# Računam fib(8)
# Računam fib(7)
# Računam fib(6)
# Računam fib(5)
# Računam fib(4)
# Računam fib(3)
# Računam fib(2)
# Računam fib(1)
# Računam fib(0)
# 1262027241743996257169366534803711153432873792011637768873717598849301425880152551659880282149947993889708136584785538962348100239436771893992147449837835103812540911951967569050060912009607003831549523998076513

# %% [markdown]
# ## Levenshteinova razdalja

# %% [markdown]
# - srečno pa zdravo
# - rečno pa zdravo
# - večno pa zdravo
# - vesčno pa zdravo
# - veseno pa zdravo
# - veselo pa zdravo
# - veselo pa dravo
# - veselo pa deravo
# - veselo pa debavo
# - veselo pa debevo
# - veselo pa debelo

# %% [markdown]
# ## ↓/→ pot z najmanjšo vsoto
#
# <table>
# <tr><td><strong>131</strong></td><td> 673 </td><td> 234 </td><td> 103 </td><td> 18</td></tr>
# <tr><td><strong>201</strong></td><td><strong>96</strong></td><td> <strong>342</strong></td><td> 965 </td><td> 150</td></tr>
# <tr><td> 630 </td><td> 803 </td><td><strong>746</strong></td><td><strong>422</strong></td><td> 111</td></tr>
# <tr><td> 537 </td><td> 699 </td><td> 497 </td><td><strong>121</strong></td><td> 956</td></tr>
# <tr><td> 805 </td><td> 732 </td><td> 524 </td><td><strong>37</strong> </td><td><strong>331</strong></td></tr>
# </table>

# %%
mat = [[131, 673, 234, 103, 18],
[201, 96, 342, 965, 150],
[630, 803, 746, 422, 111],
[537, 699, 497, 121, 956],
[805, 732, 524, 37, 331]]

from functools import cache

def najdrazja_pot(mat):
    m, n = len(mat), len(mat[0])
    cene_poti = [[None for _ in vrstica] for vrstica in mat]
    cene_poti[-1][-1] = mat[-1][-1]
    for j in range(n - 2, -1, -1):
        cene_poti[-1][j] = cene_poti[-1][j + 1] + mat[-1][j]
    for i in range(m - 2, -1, -1):
        cene_poti[i][-1] = cene_poti[i + 1][-1] + mat[i][-1]
        for j in range(n - 2, -1, -1):
            cene_poti[i][j] = max(
                cene_poti[i + 1][j],
                cene_poti[i][j + 1]
            ) + mat[i][j]
    return cene_poti[0][0]

@cache  # pozor, ne dela, če je matrika seznam
def najdrazja_pot_rek(mat, i=0, j=0):
    """Najdražja pot iz mat[i][j] do konca"""
    m, n = len(mat), len(mat[0])
    if i == m - 1 and j == n - 1:
        a = 0
    elif i == m - 1:
        a = najdrazja_pot_rek(mat, i, j + 1)
    elif j == n - 1:
        a = najdrazja_pot_rek(mat, i + 1, j)
    else:
        a = max(
            najdrazja_pot_rek(mat, i + 1, j),
            najdrazja_pot_rek(mat, i, j + 1),
        )
    return mat[i][j] + a

def najdrazja_pot_cache(mat):
    m, n = len(mat), len(mat[0])
    @cache
    def pomozna(i, j):
        """Najdražja pot iz mat[i][j] do konca"""
        if i == m - 1 and j == n - 1:
            a = 0
        elif i == m - 1:
            a = pomozna(i, j + 1)
        elif j == n - 1:
            a = pomozna(i + 1, j)
        else:
            a = max(
                pomozna(i + 1, j),
                pomozna(i, j + 1),
            )
        return mat[i][j] + a
    return pomozna(0, 0)

# %%
tuple(tuple(vrs) for vrs in mat)
# Out:
# ((131, 673, 234, 103, 18),
#  (201, 96, 342, 965, 150),
#  (630, 803, 746, 422, 111),
#  (537, 699, 497, 121, 956),
#  (805, 732, 524, 37, 331))

# %%
# %timeit najdrazja_pot(mat)
# Out:
# 5.09 µs ± 12.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
tt = tuple(tuple(vrs) for vrs in mat)
# %timeit -n 1 -r 1000000 najdrazja_pot.clear_cache(); najdrazja_pot_rek(tt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 tt = tuple(tuple(vrs) for vrs in mat)
# ----> 2 get_ipython().run_line_magic('timeit', '-n 1 -r 1000000 najdrazja_pot.clear_cache(); najdrazja_pot_rek(tt)')
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/magics/execution.py:1189, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1186         if time_number >= 0.2:
#    1187             break
# -> 1189 all_runs = timer.repeat(repeat, number)
#    1190 best = min(all_runs) / number
#    1191 worst = max(all_runs) / number
#
# File /opt/homebrew/Cellar/python@3.10/3.10.13/Frameworks/Python.framework/Versions/3.10/lib/python3.10/timeit.py:206, in Timer.repeat(self, repeat, number)
#     204 r = []
#     205 for i in range(repeat):
# --> 206     t = self.timeit(number)
#     207     r.append(t)
#     208 return r
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# AttributeError: 'function' object has no attribute 'clear_cache'

# %%
# %timeit

# %%
# %timeit -n 1 -r 1000000 najdrazja_pot_cache(mat)
# Out:
# The slowest run took 25.66 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10.1 µs ± 1.83 µs per loop (mean ± std. dev. of 1000000 runs, 1 loop each)

# %%
# %timeit najdrazja_pot_cache(tuple(tuple(vrs) for vrs in mat))
# Out:
# 9.06 µs ± 49.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
