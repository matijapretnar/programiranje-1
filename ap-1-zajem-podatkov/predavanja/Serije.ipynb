# %%
import pandas as pd

# %%
serije = pd.read_csv('serije.csv', index_col='id')

# %%
serije
# Out:
#                                       ime oznaka  leto_zacetka  leto_konca  \
# id
# 944947                     Igra prestolov    NaN          2011         NaN
# 903747                         Kriva pota    NaN          2008      2013.0
# 1520211                      Zivi mrtveci    NaN          2010         NaN
# 1475582                          Sherlock    NaN          2010         NaN
# 898266                     Veliki pokovci    NaN          2007         NaN
# 108778                         Prijatelji    NaN          1994      2004.0
# 773262                             Dexter    NaN          2006      2013.0
# 460649       Kako sem spoznal vajino mamo    NaN          2005      2014.0
# 411008                   Skrivnostni otok    NaN          2004      2010.0
# 455275                      Beg iz zapora    NaN          2005         NaN
# 1856010                    House of Cards    NaN          2013         NaN
# ...

# %%
series.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f9f064d12c2a> in <module>()
# ----> 1 series.head()
#
# NameError: name 'series' is not defined

# %%
serije.head()
# Out:
#                     ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 944947   Igra prestolov    NaN          2011         NaN    9.5
# 903747       Kriva pota    NaN          2008      2013.0    9.5
# 1520211    Zivi mrtveci    NaN          2010         NaN    8.5
# 1475582        Sherlock    NaN          2010         NaN    9.2
# 898266   Veliki pokovci    NaN          2007         NaN    8.3
#
#                                                       opis  stevilo_glasov  \
# id
# 944947   Nine noble families fight for control over the...         1241629
# 903747   A high school chemistry teacher diagnosed with...         1023499
# 1520211  Sheriff Deputy Rick Grimes wakes up from a com...          710538
# 1475582  A modern update finds the famous sleuth and hi...          602975
# 898266   A woman who moves into an apartment across the...          579154
#
#          dolzina
# id
# 944947      57.0
# 903747      49.0
# 1520211     44.0
# 1475582     88.0
# 898266      22.0

# %%
serije.tail()
# Out:
#                                   ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 264244   Il était une fois... l'homme    NaN          1978         NaN    8.1
# 202741                   The Man Show    NaN          1999      2014.0    6.8
# 377253               Rosemary & Thyme    NaN          2003      2006.0    7.7
# 112225                       Wishbone    NaN          1995      1998.0    8.4
# 5537534                          Ajin    NaN          2016         NaN    7.8
#
#                                                       opis  stevilo_glasov  \
# id
# 264244   A comprehensive animated survey of the evoluti...            2668
# 202741   A comedic talk show geared toward men, and the...            2662
# 377253   Set amongst the stunning gardens of Europe, Ro...            2656
# 112225   An intelligent and witty dog imagines himself ...            2656
# 5537534  17 years ago, immortals first appeared on the ...            2646
#
#          dolzina
# id
# ...

# %%
serije[30:40]
# Out:
#                          ime oznaka  leto_zacetka  leto_konca  ocena  \
# id
# 475784             Westworld    NaN          2016         NaN    9.0
# 2802850                Fargo    NaN          2014         NaN    9.0
# 1844624  Ameriska grozljivka    NaN          2011         NaN    8.2
# 141842             Sopranovi    NaN          1999      2007.0    9.2
# 306414        Skrivna naveza    NaN          2002      2008.0    9.3
# 2707408               Narcos    NaN          2015         NaN    8.9
# 369179       Dva moza in pol    NaN          2003      2015.0    7.1
# 844441             Prava kri    NaN          2008      2014.0    7.9
# 813715                Heroji     II          2006      2010.0    7.7
# 285403       Mladi zdravniki    NaN          2001      2010.0    8.4
#
#                                                       opis  stevilo_glasov  \
# id
# 475784   Set at the intersection of the near future and...          220165
# ...

# %%
serije['ime']
# Out:
# id
# 944947                       Igra prestolov
# 903747                           Kriva pota
# 1520211                        Zivi mrtveci
# 1475582                            Sherlock
# 898266                       Veliki pokovci
# 108778                           Prijatelji
# 773262                               Dexter
# 460649         Kako sem spoznal vajino mamo
# 411008                     Skrivnostni otok
# 455275                        Beg iz zapora
# 1856010                      House of Cards
# 2356777                      Pravi detektiv
# 4574334                     Stranger Things
# 2193021                             Puscica
# 412142                     Zdravnikova vest
# 460681                           Nadnaravno
# 96697                            Simpsonovi
# 1632701                Nepremagljivi dvojec
# 1442437                     Sodobna družina
# 3322312                           Daredevil
# 121955                           South Park
# ...

# %%
serije[['ime', 'leto_zacetka']]
# Out:
#                                       ime  leto_zacetka
# id
# 944947                     Igra prestolov          2011
# 903747                         Kriva pota          2008
# 1520211                      Zivi mrtveci          2010
# 1475582                          Sherlock          2010
# 898266                     Veliki pokovci          2007
# 108778                         Prijatelji          1994
# 773262                             Dexter          2006
# 460649       Kako sem spoznal vajino mamo          2005
# 411008                   Skrivnostni otok          2004
# 455275                      Beg iz zapora          2005
# 1856010                    House of Cards          2013
# 2356777                    Pravi detektiv          2014
# 4574334                   Stranger Things          2016
# 2193021                           Puscica          2012
# 412142                   Zdravnikova vest          2004
# 460681                         Nadnaravno          2005
# ...

# %%
serije[serije['leto_zacetka'] == 2003]
# Out:
#                                              ime oznaka  leto_zacetka  \
# id
# 367279                            Odbita rodbina    NaN          2003
# 369179                           Dva moza in pol    NaN          2003
# 364845                Preiskovalci na delu: NCIS    NaN          2003
# 362359                                  The O.C.    NaN          2003
# 368530                             One Tree Hill    NaN          2003
# 361217                          Pod nozem lepote    NaN          2003
# 383126                               MythBusters    NaN          2003
# 421357                  Hagane no renkinjutsushi    NaN          2003
# 353049                          Chappelle's Show    NaN          2003
# 387764                                 Peep Show    NaN          2003
# 319969                                 Carnivàle    NaN          2003
# 348913                              Dead Like Me    NaN          2003
# ...

# %%
serije[
    (serije['leto_zacetka'] == 2003)
    &
    (serije['ocena'] > 8)
].sort_values(
    'dolzina'
)[
    ['ime', 'stevilo_glasov']
]
# Out:
#                                              ime  stevilo_glasov
# id
# 401747  Red vs. Blue: The Blood Gulch Chronicles            7923
# 353049                          Chappelle's Show           40443
# 417373                         The Venture Bros.           20104
# 421357                  Hagane no renkinjutsushi           45227
# 387764                                 Peep Show           39559
# 380136                                        QI           25231
# 416394                          The Mighty Boosh           17299
# 346369                  Penn & Teller: Bullshit!           10872
# 383126                               MythBusters           47406
# 319969                                 Carnivàle           37130
# 348913                              Dead Like Me           36133
# 367279                            Odbita rodbina          230278
# 367439                               Wolf's Rain            6112
# ...

# %%
serije.groupby('leto_zacetka').mean().tail(15)
# Out:
#                leto_konca     ocena  stevilo_glasov    dolzina
# leto_zacetka
# 2003          2007.414634  7.328070    24105.964912  60.222222
# 2004          2008.844444  7.576190    30844.714286  53.262295
# 2005          2009.439024  7.497143    46675.314286  39.636364
# 2006          2010.045455  7.519298    32148.228070  41.735849
# 2007          2011.127660  7.529268    25761.121951  41.920000
# 2008          2011.170213  7.544262    39833.377049  43.000000
# 2009          2012.653061  7.365000    32372.900000  42.815789
# 2010          2013.345455  7.624731    33747.236559  44.318182
# 2011          2013.634921  7.485714    37234.230159  41.188525
# 2012          2014.137255  7.510619    16787.221239  43.538462
# 2013          2014.960000  7.591892    31029.684685  42.935780
# 2014          2015.473684  7.669919    24349.195122  43.798319
# 2015          2016.444444  7.645038    23205.381679  43.669231
# 2016          2017.000000  7.553333    15608.025000  52.386555
# ...

# %%
serije.groupby('leto_zacetka').mean()['ocena']
# Out:
# leto_zacetka
# 1951    8.400000
# 1955    8.400000
# 1957    7.633333
# 1959    8.150000
# 1960    7.460000
# 1961    7.675000
# 1962    7.575000
# 1963    7.833333
# 1964    7.766667
# 1965    7.462500
# 1966    7.916667
# 1967    8.700000
# 1968    8.040000
# 1969    7.975000
# 1970    8.100000
# 1971    8.075000
# 1972    8.044444
# 1973    7.180000
# 1974    7.655556
# 1975    7.600000
# 1976    7.185714
# 1977    7.260000
# 1978    7.640000
# 1979    6.875000
# 1980    8.100000
# 1981    7.550000
# 1982    7.600000
# 1983    7.612500
# 1984    7.370588
# 1985    7.294444
#           ...
# 1988    7.700000
# 1989    7.455556
# 1990    7.745455
# 1991    7.335714
# 1992    7.343478
# 1993    7.546875
# 1994    7.693548
# 1995    7.520588
# 1996    7.337931
# 1997    7.420000
# 1998    7.206452
# 1999    7.894872
# 2000    7.515152
# 2001    7.520930
# 2002    7.417949
# 2003    7.328070
# 2004    7.576190
# 2005    7.497143
# 2006    7.519298
# 2007    7.529268
# 2008    7.544262
# ...

# %%
serije['petletka'] = 5 * ((serije['leto_zacetka'] - 2) // 5) + 2

# %%
serije
# Out:
#                                       ime oznaka  leto_zacetka  leto_konca  \
# id
# 944947                     Igra prestolov    NaN          2011         NaN
# 903747                         Kriva pota    NaN          2008      2013.0
# 1520211                      Zivi mrtveci    NaN          2010         NaN
# 1475582                          Sherlock    NaN          2010         NaN
# 898266                     Veliki pokovci    NaN          2007         NaN
# 108778                         Prijatelji    NaN          1994      2004.0
# 773262                             Dexter    NaN          2006      2013.0
# 460649       Kako sem spoznal vajino mamo    NaN          2005      2014.0
# 411008                   Skrivnostni otok    NaN          2004      2010.0
# 455275                      Beg iz zapora    NaN          2005         NaN
# 1856010                    House of Cards    NaN          2013         NaN
# ...

# %%
serije.groupby('petletka').mean()
# Out:
#           leto_zacetka   leto_konca     ocena  stevilo_glasov    dolzina
# petletka
# 1947       1951.000000  1957.000000  8.400000    18807.000000  30.000000
# 1952       1955.000000  1964.333333  8.400000     6144.333333  38.333333
# 1957       1959.500000  1968.500000  7.657143    11586.571429  37.142857
# 1962       1964.333333  1969.320000  7.688889     9147.333333  38.740741
# 1967       1969.047619  1980.050000  8.090476     9567.047619  45.238095
# 1972       1973.973684  1979.764706  7.586842     8774.973684  43.263158
# 1977       1978.931034  1986.185185  7.475862     8237.689655  53.689655
# 1982       1984.166667  1989.123077  7.458333     9788.083333  46.791667
# 1987       1989.047059  1995.549296  7.592941    22405.223529  48.940476
# 1992       1994.093960  2000.165354  7.499329    16699.852349  44.455782
# 1997       1999.099448  2004.465278  7.527072    25969.022099  48.161111
# 2002       2004.171329  2008.599010  7.474476    32848.975524  47.651852
# ...

# %%
serije[
    (serije['ocena'] > 8.5) & (serije['leto_zacetka'] < 2017)
].groupby('petletka').size().plot()

# %%
serije[
    (serije['ocena'] < 6) & (serije['leto_zacetka'] < 2017)
].groupby('petletka').size().plot()

# %%
serije.groupby('petletka').mean()['ocena'].plot()

# %%
# %matplotlib inline
